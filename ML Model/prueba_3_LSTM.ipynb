# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from keras.utils import plot_model
from datetime import date
import holidays
from keras.optimizers import Adam
from sklearn.model_selection import TimeSeriesSplit, cross_val_score
from scikeras.wrappers import KerasRegressor
import time
# Out:
# WARNING:tensorflow:From c:\Users\alter\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df = pd.read_parquet('data_export/prueba_ml.parquet')
df.reset_index(inplace=True, drop=True)
df['dia_semana'] = df['fecha'].dt.weekday + 1
year = 2023
us_holidays = holidays.US(years=year)
us_holidays
df['holiday'] = np.where(df['fecha'].isin(us_holidays), 1, 0)
df['rain'] = df['rain'].shift(1)
df['snowfall'] = df['snowfall'].shift(1)
df.fillna(0.0, inplace=True)

# %%
df.head()
# Out:
#        fecha  hora  temperature_2m  rain  relative_humidity_2m  snowfall  \
# 0 2023-11-01   0.0          8.6725   0.0             60.153034       0.0
# 1 2023-11-01   1.0          8.5725   0.1             60.344471       0.0
# 2 2023-11-01   2.0          8.3225   0.0             62.933163       0.0
# 3 2023-11-01   3.0          8.0725   0.1             66.100021       0.0
# 4 2023-11-01   4.0          7.7725   0.0             72.938622       0.0
#
#    Bronx  Brooklyn  Manhattan  Queens  Staten Island   año  mes  dia  \
# 0      3        12       2196     232              1  2023   11    1
# 1      2        12       1521      55              0  2023   11    1
# 2      3         8       1214      16              0  2023   11    1
# 3      0        13        854      20              0  2023   11    1
# 4     12        20        654      25              0  2023   11    1
#
#    dia_semana  holiday
# 0           3        0
# 1           3        0
# 2           3        0
# 3           3        0
# 4           3        0

# %%
columnas_X = ['año', 'mes', 'dia', 'hora', 'dia_semana', 'holiday', 'temperature_2m', 'rain', 'relative_humidity_2m', 'snowfall']
X = df[columnas_X]

columnas_Y= ['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island']
Y = df[columnas_Y]

# %%
def generador_X_Y(X, Y, p):
    ''' 
    A partir dos dataframes, X e Y, y los pasos de tiempo, retorna un tensor 3D para X y una array 2D para Y.
    args:
    - X: pandas dataframe, con m filas (muestras) y n columnas (features)
    - Y: pandas dataframe, con m filas (muestras) e y columnas (longitud de vector de respuesta)
    - p (int): número de pasos de tiempo a considerar
    returns:
    - X_reshaped: numpy array de forma (m, p, n)
    - Y_reshaped: numpy array de forma (m, y)
    '''
    
    X_reshaped_list = list()
    Y_rehaped_list = list()

    m = len(X)
    X = np.array(X)
    Y = np.array(Y)

    for i in range(m-p):
        X_reshaped_list.append(X[i:i+p, :])
        Y_rehaped_list.append(Y[i+p-1, :])
    
    X_reshaped = np.array(X_reshaped_list)
    Y_reshaped = np.array(Y_rehaped_list)

    return X_reshaped, Y_reshaped

# %%
def crear_modelo(X_reshaped, Y_reshaped, nro_capas_lstm=1, unidades_capa= [50], nro_capas_dense=0, unidades_dense=[0], loss_= 'mse', 
                 act_salida='linear', act_lstm= 'relu', drop_out= 0, learning_r=0.001, act_dense= 'linear'):
    
    # Construimos el modelo LSTM
    model = Sequential()
    if nro_capas_lstm > 1:

        model.add(LSTM(units=unidades_capa[0], activation=act_lstm, input_shape=(X_reshaped.shape[1], X_reshaped.shape[2]), return_sequences=True))
        model.add(Dropout(drop_out))
        for i in range(1, nro_capas_lstm-1):
            model.add(LSTM(units=unidades_capa[i], activation=act_lstm, return_sequences=True))
            model.add(Dropout(drop_out))
        model.add(LSTM(units=unidades_capa[-1], activation=act_lstm))
        
    if nro_capas_lstm == 1:
        model.add(LSTM(units=unidades_capa[0], activation=act_lstm, input_shape=(X_reshaped.shape[1], X_reshaped.shape[2])))
        model.add(Dropout(drop_out))
    
    if nro_capas_dense > 0:
        for i in range(nro_capas_dense):
            model.add(Dense(units=unidades_dense[i], activation=act_dense))
    
    model.add(Dense(units=Y_reshaped.shape[1], activation=act_salida))

    opt = Adam(learning_rate=learning_r)

    model.compile(optimizer=opt, loss=loss_)  # Compilación del modelo 
    
    #model.summary()

    return model

# %%
def construir_modelo(X, Y, nro_pasos=10, nro_capas_lstm=1, unidades_capa= [50], nro_capas_dense=0, unidades_dense=[0], loss_= 'mse', act_salida='linear', 
                     act_lstm= 'relu', act_dense= 'linear', epochs= 50, batch= 32, drop_out= 0, scaler= 'minmax', learning_r=0.1):
    # Normalizar los datos
    if scaler == 'minmax':
        scaler_X = MinMaxScaler()
        scaler_Y = MinMaxScaler()
    if scaler == 'standard':
        scaler_X = StandardScaler()
        scaler_Y = StandardScaler()

    X_scaled = scaler_X.fit_transform(X)
    Y_scaled = scaler_Y.fit_transform(Y)

    # Dividir los datos en conjuntos de entrenamiento y prueba
    X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y_scaled, test_size=0.2, shuffle=False)

    # Reshape de los datos para que sean 3D (número de muestras, número de pasos de tiempo, número de características)
    X_train_reshaped, Y_train_reshaped = generador_X_Y(X_train, Y_train, nro_pasos)
    X_test_reshaped, Y_test_reshaped = generador_X_Y(X_test, Y_test, nro_pasos)

    # Construimos el modelo LSTM
    model = Sequential()
    if nro_capas_lstm > 1:

        model.add(LSTM(units=unidades_capa[0], activation=act_lstm, input_shape=(X_train_reshaped.shape[1], X_train_reshaped.shape[2]), return_sequences=True))
        model.add(Dropout(drop_out))
        for i in range(1, nro_capas_lstm-1):
            model.add(LSTM(units=unidades_capa[i], activation=act_lstm, return_sequences=True))
            model.add(Dropout(drop_out))
        model.add(LSTM(units=unidades_capa[-1], activation=act_lstm))
    
    
    if nro_capas_lstm == 1:
        model.add(LSTM(units=unidades_capa[0], activation=act_lstm, input_shape=(X_train_reshaped.shape[1], X_train_reshaped.shape[2])))
        model.add(Dropout(drop_out))
    
    if nro_capas_dense > 0:
        for i in range(nro_capas_dense):
            model.add(Dense(units=unidades_dense[i], activation=act_dense))
    
    model.add(Dense(units=Y_train_reshaped.shape[1], activation=act_salida))

    opt = Adam(learning_rate=learning_r)

    model.compile(optimizer=opt, loss=loss_)  # Compilación del modelo 
    
    model.summary()

    # Entrenamos el modelo y guardamos el historial de entrenamiento
    history = model.fit(X_train_reshaped, Y_train_reshaped, epochs=epochs, batch_size=batch, validation_data=(X_test_reshaped, Y_test_reshaped), verbose=0)

    return model, scaler_X, scaler_Y, X_test_reshaped, Y_test_reshaped, history

# %% [markdown]
# Vamos a generar una nueva función que haga una cross validation antes de entrenar el modelo a retornar

# %%
def construir_modelo_cv(X, Y, nro_pasos=10, nro_capas_lstm=1, unidades_capa= [50], loss_= 'mse', act_salida='linear', act_lstm= 'relu', 
                     epochs= 50, batch= 32, drop_out= 0, scaler= 'minmax', learning_r=0.001, nro_capas_dense=0, unidades_dense=[0], 
                     act_dense= 'linear'):
    # Normalizar los datos
    if scaler == 'minmax':
        scaler_X = MinMaxScaler()
        scaler_Y = MinMaxScaler()
    if scaler == 'standard':
        scaler_X = StandardScaler()
        scaler_Y = StandardScaler()

    X_scaled = scaler_X.fit_transform(X)
    Y_scaled = scaler_Y.fit_transform(Y)

    X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y_scaled, test_size=0.2, shuffle=False)

    # Reshape de los datos para que sean 3D (número de muestras, número de pasos de tiempo, número de características)
    X_train_reshaped, Y_train_reshaped = generador_X_Y(X_train, Y_train, nro_pasos)
    X_test_reshaped, Y_test_reshaped = generador_X_Y(X_test, Y_test, nro_pasos)

    # Envolvemos el modelo en un estimador de Scikit-Learn
    estimator = KerasRegressor(
        build_fn=crear_modelo,
        X_reshaped=X_train_reshaped,
        Y_reshaped=Y_train_reshaped,
        nro_capas_lstm=nro_capas_lstm,
        unidades_capa=unidades_capa,
        nro_capas_dense = nro_capas_dense,
        unidades_dense = unidades_dense,
        loss_=loss_,
        act_salida= act_salida,
        act_lstm= act_lstm,
        act_dense = act_dense,
        drop_out=drop_out,
        learning_r=learning_r,
        epochs=epochs,
        batch_size=batch,
        verbose=0
    )

    # Usamos el regresor en cross_val_score

    tscv = TimeSeriesSplit(n_splits=5)
    scores = cross_val_score(estimator, X_train_reshaped, Y_train_reshaped, cv=tscv, scoring='neg_mean_squared_error', verbose=0)

    # entrenamos el modelo

    modelo = crear_modelo(X_train_reshaped, Y_train_reshaped, nro_capas_lstm, unidades_capa, nro_capas_dense, unidades_dense, loss_, 
                    act_salida, act_lstm, drop_out, learning_r, act_dense)
    
    history = modelo.fit(X_train_reshaped, Y_train_reshaped, epochs=epochs, batch_size=batch, validation_data=(X_test_reshaped, Y_test_reshaped), verbose=0)

    if loss_ == 'mse':
        loss = modelo.evaluate(X_test_reshaped, Y_test_reshaped)
    else:
        y_pred = modelo.predict(X_test_reshaped)
        loss = np.mean(tf.keras.losses.mean_squared_error(Y_test_reshaped, y_pred).numpy())

    return modelo, scaler_X, scaler_Y, X_test_reshaped, Y_test_reshaped, scores, history, loss

# %%
def graficar_curva_aprendizaje(history):
    # Extraemos los valores de la función de pérdida del historial de entrenamiento
    train_loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    final_loss = history.history['val_loss'][-1]
    print("Valor final de Loss:", final_loss)
    
    # Graficamos la curva de aprendizaje
    plt.plot(train_loss, label='Train Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Curva de Aprendizaje')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
def graficar_pred_test(X_test_reshaped, Y_test_reshaped, modelo, scaler_Y):
    Y_test_df = pd.DataFrame(Y_test_reshaped, columns=columnas_Y)
    Y_test_original = scaler_Y.inverse_transform(Y_test_df)
    Y_test_original_df = pd.DataFrame(Y_test_original, columns=columnas_Y)

    Y_predict = modelo.predict(X_test_reshaped)
    Y_predict_df = pd.DataFrame(Y_predict, columns=columnas_Y)
    Y_predict_original = scaler_Y.inverse_transform(Y_predict_df)
    Y_predict_original_df = pd.DataFrame(Y_predict_original, columns=columnas_Y)

    for i in columnas_Y:
        sns.lineplot(x=Y_predict_original_df.index, y=Y_predict_original_df[i], label='Predicción')
        sns.lineplot(x=Y_test_original_df.index, y=Y_test_original_df[i], label= 'Real')
        plt.xticks(rotation=45)
        plt.legend()
        plt.show()

# %% [markdown]
# Agreguemos una nueva función que genere una evaluación exhaustiva de los parámetros y los almacene en un dataframe:

# %%
def evaluar_modelos(X, Y, nro_pasos=25, nro_capas_lstm=[1], unidades_capa= [50], loss_= ['mse', 'mae'], act_salida=['linear'], act_lstm= ['relu'],
                    nro_capas_dense=0, unidades_dense=[0], act_dense= ['linear'], drop_out=0, scaler='minmax'):

    columnas = ['combinacion','nro_pasos', 'nro_capas_lstm', 'unidades_capa', 'nro_capas_dense', 'unidades_dense',  
                'loss_function', 'act_salida', 'act_lstm', 'act_dense', 'loss_value(mse)', 'cv_scores_mean', 'tiempo(s)']

    evaluacion = pd.DataFrame(columns=columnas)
    i = 0
    combinaciones = nro_pasos*len(nro_capas_lstm)*len(loss_)*len(act_salida)*len(act_lstm)
    mejor_score = float('inf')
    mejor_combinacion = 0
    for pasos in range(1,nro_pasos+1):
        for capas in nro_capas_lstm:
            for loss_f in loss_:
                for act_s in act_salida:
                    for act_l in act_lstm:
                        for capas_dense in range(nro_capas_dense):
                            for act_d in act_dense:
                                start_time = time.time()
                                _, _, _, _, _, scores, _, loss = construir_modelo_cv(X, Y, pasos, capas, unidades_capa, loss_f, act_s, act_l,
                                                                                    drop_out=drop_out, nro_capas_dense=capas_dense, 
                                                                                    unidades_dense=unidades_dense, act_dense=act_d,
                                                                                    scaler=scaler)
                                end_time = time.time()
                                tiempo = end_time - start_time
                                unidades_capa_str = ', '.join(map(str, unidades_capa[0:capas]))
                                unidades_dense_str = ', '.join(map(str, unidades_dense[0:capas]))
                                scores_mean = np.mean(-scores)
                                evaluacion.loc[i] = [i+1, pasos, capas, unidades_capa_str, nro_capas_dense, unidades_dense_str,
                                                    loss_f, act_s, act_l, act_d, loss, scores_mean, tiempo]
                                tiempo_promedio = np.mean(evaluacion['tiempo(s)'])
                                i+=1
                                if scores_mean < mejor_score:
                                    mejor_combinacion = i
                                    mejor_score = scores_mean
                                print(f'Finalizada combinación {i} de {combinaciones}. Score= {np.round(scores_mean, 3)}')
                                print(f'Mejor combinación: {mejor_combinacion}. Score: {np.round(mejor_score, 3)}')
                                tiempo_restante = tiempo_promedio * (combinaciones - i) / 60
                                print(f'Quedan {round(tiempo_restante, 2)} minutos.')
    
    return evaluacion

# %%
model, scaler_X, scaler_Y, X_test_reshaped, Y_test_reshaped, history = construir_modelo(
    X, Y, nro_pasos=20, nro_capas_lstm=3, unidades_capa=[50,30,20], act_lstm= 'sigmoid', scaler='standard'
)
# Out:
# WARNING:tensorflow:From c:\Users\alter\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\alter\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 20, 50)            12200
#
#  dropout (Dropout)           (None, 20, 50)            0
#
#  lstm_1 (LSTM)               (None, 20, 30)            9720
#
#  dropout_1 (Dropout)         (None, 20, 30)            0
#
#  lstm_2 (LSTM)               (None, 20)                4080
#
#  dense (Dense)               (None, 5)                 105
#
# =================================================================
# Total params: 26105 (101.97 KB)
# Trainable params: 26105 (101.97 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# WARNING:tensorflow:From c:\Users\alter\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.

# %%
graficar_curva_aprendizaje(history)
# Out:
# Valor final de Loss: 0.7598069310188293

# %% [markdown]
# Vemos que la curva de aprendizaje diverge de validación diverge, y que la curva de entrenamiento puede seguir bajando. Cambiemos primero la tasa de aprendizaje.

# %%
model, scaler_X, scaler_Y, X_test_reshaped, Y_test_reshaped, history = construir_modelo(
    X, Y, nro_pasos=20, nro_capas_lstm=3, unidades_capa=[50,30,20], act_lstm= 'sigmoid', scaler='standard',
    learning_r=0.0001
)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 20, 50)            12200
#
#  dropout_4 (Dropout)         (None, 20, 50)            0
#
#  lstm_7 (LSTM)               (None, 20, 30)            9720
#
#  dropout_5 (Dropout)         (None, 20, 30)            0
#
#  lstm_8 (LSTM)               (None, 20)                4080
#
#  dense_2 (Dense)             (None, 5)                 105
#
# =================================================================
# Total params: 26105 (101.97 KB)
# Trainable params: 26105 (101.97 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
graficar_curva_aprendizaje(history)
# Out:
# Valor final de Loss: 0.8120893836021423

# %% [markdown]
# Vemos que al disminuir la tasa de aprendizaje mejoran las curvas, pero ahora tenemos la de validación por debajo de la de entrenamiento. Aumentemos la cantidad de epochs:

# %%
model, scaler_X, scaler_Y, X_test_reshaped, Y_test_reshaped, history = construir_modelo(
    X, Y, nro_pasos=20, nro_capas_lstm=3, unidades_capa=[50,30,20], act_lstm= 'sigmoid', scaler='standard',
    learning_r=0.0001, epochs=100
)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 20, 50)            12200
#
#  dropout_6 (Dropout)         (None, 20, 50)            0
#
#  lstm_10 (LSTM)              (None, 20, 30)            9720
#
#  dropout_7 (Dropout)         (None, 20, 30)            0
#
#  lstm_11 (LSTM)              (None, 20)                4080
#
#  dense_3 (Dense)             (None, 5)                 105
#
# =================================================================
# Total params: 26105 (101.97 KB)
# Trainable params: 26105 (101.97 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
graficar_curva_aprendizaje(history)
# Out:
# Valor final de Loss: 0.5650769472122192

# %% [markdown]
# Las curvas mejoran, pero no tenemos una buena pérdida final. Grafiquemos para ver como se comportan las predicciones:

# %%
graficar_pred_test(X_test_reshaped, Y_test_reshaped, model, scaler_Y)
# Out:
# 9/9 [==============================] - 0s 6ms/step

# %% [markdown]
# Probemos ahora escalando con minmax:

# %%
model, scaler_X, scaler_Y, X_test_reshaped, Y_test_reshaped, history = construir_modelo(
    X, Y, nro_pasos=20, nro_capas_lstm=3, unidades_capa=[50,30,20], act_lstm= 'sigmoid', scaler='minmax',
    learning_r=0.0001, epochs=100
)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 20, 50)            12200
#
#  dropout_8 (Dropout)         (None, 20, 50)            0
#
#  lstm_13 (LSTM)              (None, 20, 30)            9720
#
#  dropout_9 (Dropout)         (None, 20, 30)            0
#
#  lstm_14 (LSTM)              (None, 20)                4080
#
#  dense_4 (Dense)             (None, 5)                 105
#
# =================================================================
# Total params: 26105 (101.97 KB)
# Trainable params: 26105 (101.97 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
graficar_curva_aprendizaje(history)
# Out:
# Valor final de Loss: 0.029366884380578995

# %% [markdown]
# Vemos que hay sobreajuste además que con 25 epochs el modelo ya había convergido. Veamos que sucede si agregamos dropout:

# %%
model, scaler_X, scaler_Y, X_test_reshaped, Y_test_reshaped, history = construir_modelo(
    X, Y, nro_pasos=20, nro_capas_lstm=3, unidades_capa=[50,30,20], act_lstm= 'sigmoid', scaler='minmax',
    learning_r=0.0001, epochs=100, drop_out=0.2
)
graficar_curva_aprendizaje(history)
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_15 (LSTM)              (None, 20, 50)            12200
#
#  dropout_10 (Dropout)        (None, 20, 50)            0
#
#  lstm_16 (LSTM)              (None, 20, 30)            9720
#
#  dropout_11 (Dropout)        (None, 20, 30)            0
#
#  lstm_17 (LSTM)              (None, 20)                4080
#
#  dense_5 (Dense)             (None, 5)                 105
#
# =================================================================
# Total params: 26105 (101.97 KB)
# Trainable params: 26105 (101.97 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Valor final de Loss: 0.029474465176463127

# %% [markdown]
# Sigue habiendo sobreajuste. Probemos reducir la cantidad de neuronas por capa:

# %%
model, scaler_X, scaler_Y, X_test_reshaped, Y_test_reshaped, history = construir_modelo(
    X, Y, nro_pasos=20, nro_capas_lstm=3, unidades_capa=[30,20,10], act_lstm= 'sigmoid', scaler='minmax',
    learning_r=0.0001, epochs=50, drop_out=0.2
)
graficar_curva_aprendizaje(history)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_21 (LSTM)              (None, 20, 30)            4920
#
#  dropout_14 (Dropout)        (None, 20, 30)            0
#
#  lstm_22 (LSTM)              (None, 20, 20)            4080
#
#  dropout_15 (Dropout)        (None, 20, 20)            0
#
#  lstm_23 (LSTM)              (None, 10)                1240
#
#  dense_7 (Dense)             (None, 5)                 55
#
# =================================================================
# Total params: 10295 (40.21 KB)
# Trainable params: 10295 (40.21 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Valor final de Loss: 0.029157062992453575

# %% [markdown]
# Volvamos a modelos de una sola capa LSTM:

# %%
modelo, scaler_X, scaler_Y, X_test_reshaped, Y_test_reshaped, scores, history = construir_modelo_cv(
    X, Y, nro_pasos=20, nro_capas_lstm=1, act_lstm= 'sigmoid', scaler='minmax',
    learning_r=0.001, epochs=50
)
# Out:
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_40 (LSTM)              (None, 50)                12200
#
#  dropout_32 (Dropout)        (None, 50)                0
#
#  dense_24 (Dense)            (None, 5)                 255
#
# =================================================================
# Total params: 12455 (48.65 KB)
# Trainable params: 12455 (48.65 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_41 (LSTM)              (None, 50)                12200
#
#  dropout_33 (Dropout)        (None, 50)                0
#
#  dense_25 (Dense)            (None, 5)                 255
#
# =================================================================
# Total params: 12455 (48.65 KB)
# Trainable params: 12455 (48.65 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_42 (LSTM)              (None, 50)                12200
#
#  dropout_34 (Dropout)        (None, 50)                0
#
#  dense_26 (Dense)            (None, 5)                 255
#
# =================================================================
# Total params: 12455 (48.65 KB)
# Trainable params: 12455 (48.65 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_43 (LSTM)              (None, 50)                12200
#
#  dropout_35 (Dropout)        (None, 50)                0
#
#  dense_27 (Dense)            (None, 5)                 255
#
# =================================================================
# Total params: 12455 (48.65 KB)
# Trainable params: 12455 (48.65 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential_28"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_44 (LSTM)              (None, 50)                12200
#
#  dropout_36 (Dropout)        (None, 50)                0
#
#  dense_28 (Dense)            (None, 5)                 255
#
# =================================================================
# Total params: 12455 (48.65 KB)
# Trainable params: 12455 (48.65 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_45 (LSTM)              (None, 50)                12200
#
#  dropout_37 (Dropout)        (None, 50)                0
#
#  dense_29 (Dense)            (None, 5)                 255
#
# =================================================================
# Total params: 12455 (48.65 KB)
# Trainable params: 12455 (48.65 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
np.mean(-scores)
# Out:
# 0.019580741757198112

# %%
graficar_pred_test(X_test_reshaped, Y_test_reshaped, modelo, scaler_Y )
# Out:
# 9/9 [==============================] - 0s 5ms/step

# %%
graficar_curva_aprendizaje(history)
# Out:
# Valor final de Loss: 0.020634107291698456

# %%
modelo, scaler_X, scaler_Y, X_test_reshaped, Y_test_reshaped, scores, history = construir_modelo_cv(
    X, Y, nro_pasos=5, nro_capas_lstm=1, act_lstm= 'sigmoid', scaler='minmax',
    learning_r=0.001, epochs=50
)
np.mean(-scores)
# Out:
# Model: "sequential_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_46 (LSTM)              (None, 50)                12200
#
#  dropout_38 (Dropout)        (None, 50)                0
#
#  dense_30 (Dense)            (None, 5)                 255
#
# =================================================================
# Total params: 12455 (48.65 KB)
# Trainable params: 12455 (48.65 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_47 (LSTM)              (None, 50)                12200
#
#  dropout_39 (Dropout)        (None, 50)                0
#
#  dense_31 (Dense)            (None, 5)                 255
#
# =================================================================
# Total params: 12455 (48.65 KB)
# Trainable params: 12455 (48.65 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_48 (LSTM)              (None, 50)                12200
#
#  dropout_40 (Dropout)        (None, 50)                0
#
#  dense_32 (Dense)            (None, 5)                 255
#
# =================================================================
# Total params: 12455 (48.65 KB)
# Trainable params: 12455 (48.65 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential_33"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_49 (LSTM)              (None, 50)                12200
#
#  dropout_41 (Dropout)        (None, 50)                0
#
#  dense_33 (Dense)            (None, 5)                 255
#
# =================================================================
# Total params: 12455 (48.65 KB)
# Trainable params: 12455 (48.65 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential_34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_50 (LSTM)              (None, 50)                12200
#
#  dropout_42 (Dropout)        (None, 50)                0
#
#  dense_34 (Dense)            (None, 5)                 255
#
# =================================================================
# Total params: 12455 (48.65 KB)
# Trainable params: 12455 (48.65 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential_35"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_51 (LSTM)              (None, 50)                12200
#
#  dropout_43 (Dropout)        (None, 50)                0
#
#  dense_35 (Dense)            (None, 5)                 255
#
# =================================================================
# Total params: 12455 (48.65 KB)
# Trainable params: 12455 (48.65 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 0.02119916390659147

# %%
graficar_curva_aprendizaje(history)
# Out:
# Valor final de Loss: 0.020178811624646187

# %%
graficar_pred_test(X_test_reshaped, Y_test_reshaped, modelo, scaler_Y )
# Out:
# 9/9 [==============================] - 0s 3ms/step

# %%
modelo, scaler_X, scaler_Y, X_test_reshaped, Y_test_reshaped, scores, history = construir_modelo_cv(
    X, Y, nro_pasos=5, nro_capas_lstm=1, act_lstm= 'sigmoid', scaler='minmax',
    learning_r=0.0001, epochs=100
)
np.mean(-scores)
# Out:
# Model: "sequential_36"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_52 (LSTM)              (None, 50)                12200
#
#  dropout_44 (Dropout)        (None, 50)                0
#
#  dense_36 (Dense)            (None, 5)                 255
#
# =================================================================
# Total params: 12455 (48.65 KB)
# Trainable params: 12455 (48.65 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential_37"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_53 (LSTM)              (None, 50)                12200
#
#  dropout_45 (Dropout)        (None, 50)                0
#
#  dense_37 (Dense)            (None, 5)                 255
#
# =================================================================
# Total params: 12455 (48.65 KB)
# Trainable params: 12455 (48.65 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential_38"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_54 (LSTM)              (None, 50)                12200
#
#  dropout_46 (Dropout)        (None, 50)                0
#
#  dense_38 (Dense)            (None, 5)                 255
#
# =================================================================
# Total params: 12455 (48.65 KB)
# Trainable params: 12455 (48.65 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential_39"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_55 (LSTM)              (None, 50)                12200
#
#  dropout_47 (Dropout)        (None, 50)                0
#
#  dense_39 (Dense)            (None, 5)                 255
#
# =================================================================
# Total params: 12455 (48.65 KB)
# Trainable params: 12455 (48.65 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential_40"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_56 (LSTM)              (None, 50)                12200
#
#  dropout_48 (Dropout)        (None, 50)                0
#
#  dense_40 (Dense)            (None, 5)                 255
#
# =================================================================
# Total params: 12455 (48.65 KB)
# Trainable params: 12455 (48.65 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential_41"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_57 (LSTM)              (None, 50)                12200
#
#  dropout_49 (Dropout)        (None, 50)                0
#
#  dense_41 (Dense)            (None, 5)                 255
#
# =================================================================
# Total params: 12455 (48.65 KB)
# Trainable params: 12455 (48.65 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 0.027620105466752913

# %%
graficar_curva_aprendizaje(history)
# Out:
# Valor final de Loss: 0.019767524674534798

# %%
graficar_pred_test(X_test_reshaped, Y_test_reshaped, modelo, scaler_Y )
# Out:
# 9/9 [==============================] - 0s 2ms/step

# %%
df_eval = evaluar_modelos(X,Y,nro_pasos=3,nro_capas_lstm=[1,2], unidades_capa=[50,30])
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0140
# Finalizada combinación 1 de 12. Score= 0.02
# Mejor combinación: 1. Score: 0.02
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 2 de 12. Score= 0.017
# Mejor combinación: 2. Score: 0.017
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0204
# Finalizada combinación 3 de 12. Score= 0.024
# Mejor combinación: 2. Score: 0.017
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 4 de 12. Score= 0.018
# Mejor combinación: 2. Score: 0.017
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0317
# Finalizada combinación 5 de 12. Score= 0.027
# Mejor combinación: 2. Score: 0.017
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 6 de 12. Score= 0.025
# Mejor combinación: 2. Score: 0.017
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0153
# Finalizada combinación 7 de 12. Score= 0.03
# Mejor combinación: 2. Score: 0.017
# 10/10 [==============================] - 1s 3ms/step
# Finalizada combinación 8 de 12. Score= 0.036
# Mejor combinación: 2. Score: 0.017
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0163
# Finalizada combinación 9 de 12. Score= 0.021
# Mejor combinación: 2. Score: 0.017
# 10/10 [==============================] - 0s 3ms/step
# Finalizada combinación 10 de 12. Score= 0.033
# Mejor combinación: 2. Score: 0.017
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0325
# Finalizada combinación 11 de 12. Score= 0.026
# Mejor combinación: 2. Score: 0.017
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 12 de 12. Score= 0.034
# Mejor combinación: 2. Score: 0.017

# %%
df_eval.sort_values(by='cv_scores_mean')
# Out:
#     combinacion  nro_pasos  nro_capas_lstm unidades_capa loss_function  \
# 1             2          1               1            50           mae
# 3             4          1               2        50, 30           mae
# 0             1          1               1            50           mse
# 8             9          3               1            50           mse
# 2             3          1               2        50, 30           mse
# 5             6          2               1            50           mae
# 10           11          3               2        50, 30           mse
# 4             5          2               1            50           mse
# 6             7          2               2        50, 30           mse
# 9            10          3               1            50           mae
# 11           12          3               2        50, 30           mae
# 7             8          2               2        50, 30           mae
#
#    act_salida act_lstm  loss_value(mse)  cv_scores_mean  tiempo(s)
# 1      linear     relu         0.012005        0.017402  25.865024
# 3      linear     relu         0.042916        0.017614  65.620374
# 0      linear     relu         0.014008        0.020451  30.850785
# 8      linear     relu         0.016273        0.020648  38.622546
# 2      linear     relu         0.020367        0.024225  51.497537
# 5      linear     relu         0.020283        0.024683  32.269175
# 10     linear     relu         0.032546        0.025834  82.913762
# 4      linear     relu         0.031717        0.027479  68.470565
# 6      linear     relu         0.015261        0.030440  54.481554
# 9      linear     relu         0.035563        0.032623  42.713341
# 11     linear     relu         0.037974        0.033793  56.262749
# 7      linear     relu         0.016863        0.036337  96.973953

# %% [markdown]
# Ahora vamos a construir el modelo que salió mejor:

# %%
modelo, scaler_X, scaler_Y, X_test_reshaped, Y_test_reshaped, scores, history, loss = construir_modelo_cv(X, Y, nro_pasos=1, nro_capas_lstm=1, 
                                                                                        unidades_capa=[50], loss_='mae', act_lstm='relu',
                                                                                        act_salida='linear')
# Out:
# 10/10 [==============================] - 0s 2ms/step

# %%
graficar_curva_aprendizaje(history)
# Out:
# Valor final de Loss: 0.08397645503282547

# %% [markdown]
# Vemos que el modelo no converge correctamente en el entrenamiento. Cambiemos la tasa de aprendizaje:

# %%
modelo, scaler_X, scaler_Y, X_test_reshaped, Y_test_reshaped, scores, history, loss = construir_modelo_cv(X, Y, nro_pasos=1, nro_capas_lstm=1, 
                                                                                        unidades_capa=[50], loss_='mae', act_lstm='relu',
                                                                                        act_salida='linear', learning_r=0.0001, epochs=100)
graficar_curva_aprendizaje(history)
# Out:
# 10/10 [==============================] - 0s 1ms/step
# Valor final de Loss: 0.10570354759693146

# %% [markdown]
# Evaluemos nuevamente, con más combinaciones:

# %%
df_eval = evaluar_modelos(X,Y,nro_pasos=5,nro_capas_lstm=[1,2], unidades_capa=[50,30], act_lstm=['relu', 'sigmoid'], act_salida=['relu', 'linear', 'sigmoid'])
# Out:
# 10/10 [==============================] - 0s 0s/step - loss: 0.0186
# Finalizada combinación 1 de 120. Score= 0.028
# Mejor combinación: 1. Score: 0.028
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0555
# Finalizada combinación 2 de 120. Score= 0.078
# Mejor combinación: 1. Score: 0.028
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0204
# Finalizada combinación 3 de 120. Score= 0.02
# Mejor combinación: 3. Score: 0.02
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0199
# Finalizada combinación 4 de 120. Score= 0.023
# Mejor combinación: 3. Score: 0.02
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0171
# Finalizada combinación 5 de 120. Score= 0.022
# Mejor combinación: 3. Score: 0.02
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0199
# Finalizada combinación 6 de 120. Score= 0.026
# Mejor combinación: 3. Score: 0.02
# 10/10 [==============================] - 0s 1ms/step
# Finalizada combinación 7 de 120. Score= 0.029
# Mejor combinación: 3. Score: 0.02
# 10/10 [==============================] - 0s 899us/step
# Finalizada combinación 8 de 120. Score= 0.05
# Mejor combinación: 3. Score: 0.02
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 9 de 120. Score= 0.019
# Mejor combinación: 9. Score: 0.019
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 10 de 120. Score= 0.023
# Mejor combinación: 9. Score: 0.019
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 11 de 120. Score= 0.021
# Mejor combinación: 9. Score: 0.019
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 12 de 120. Score= 0.025
# Mejor combinación: 9. Score: 0.019
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0469
# Finalizada combinación 13 de 120. Score= 0.023
# Mejor combinación: 9. Score: 0.019
# 10/10 [==============================] - 0s 717us/step - loss: 0.0804
# Finalizada combinación 14 de 120. Score= 0.077
# Mejor combinación: 9. Score: 0.019
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0214
# Finalizada combinación 15 de 120. Score= 0.017
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 0s/step - loss: 0.0232
# Finalizada combinación 16 de 120. Score= 0.024
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0160
# Finalizada combinación 17 de 120. Score= 0.02
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0200
# Finalizada combinación 18 de 120. Score= 0.026
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 1ms/step
# Finalizada combinación 19 de 120. Score= 0.033
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 890us/step
# Finalizada combinación 20 de 120. Score= 0.076
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 21 de 120. Score= 0.019
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 22 de 120. Score= 0.025
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 23 de 120. Score= 0.019
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 24 de 120. Score= 0.027
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0181
# Finalizada combinación 25 de 120. Score= 0.021
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0232
# Finalizada combinación 26 de 120. Score= 0.043
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 546us/step - loss: 0.0271
# Finalizada combinación 27 de 120. Score= 0.018
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0221
# Finalizada combinación 28 de 120. Score= 0.022
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0159
# Finalizada combinación 29 de 120. Score= 0.018
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0198
# Finalizada combinación 30 de 120. Score= 0.024
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 1ms/step
# Finalizada combinación 31 de 120. Score= 0.018
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 32 de 120. Score= 0.066
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 8ms/step
# Finalizada combinación 33 de 120. Score= 0.017
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 34 de 120. Score= 0.022
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 1ms/step
# Finalizada combinación 35 de 120. Score= 0.018
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 545us/step
# Finalizada combinación 36 de 120. Score= 0.024
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0190
# Finalizada combinación 37 de 120. Score= 0.017
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0505
# Finalizada combinación 38 de 120. Score= 0.062
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0257
# Finalizada combinación 39 de 120. Score= 0.018
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0189
# Finalizada combinación 40 de 120. Score= 0.024
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0172
# Finalizada combinación 41 de 120. Score= 0.018
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0164
# Finalizada combinación 42 de 120. Score= 0.024
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 33s 10ms/step
# Finalizada combinación 43 de 120. Score= 0.028
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 44 de 120. Score= 0.041
# Mejor combinación: 15. Score: 0.017
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 45 de 120. Score= 0.016
# Mejor combinación: 45. Score: 0.016
# 10/10 [==============================] - 0s 793us/step
# Finalizada combinación 46 de 120. Score= 0.023
# Mejor combinación: 45. Score: 0.016
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 47 de 120. Score= 0.017
# Mejor combinación: 45. Score: 0.016
# 10/10 [==============================] - 1s 6ms/step
# Finalizada combinación 48 de 120. Score= 0.024
# Mejor combinación: 45. Score: 0.016
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0254
# Finalizada combinación 49 de 120. Score= 0.026
# Mejor combinación: 45. Score: 0.016
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0545
# Finalizada combinación 50 de 120. Score= 0.07
# Mejor combinación: 45. Score: 0.016
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0276
# Finalizada combinación 51 de 120. Score= 0.017
# Mejor combinación: 45. Score: 0.016
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0218
# Finalizada combinación 52 de 120. Score= 0.022
# Mejor combinación: 45. Score: 0.016
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0189
# Finalizada combinación 53 de 120. Score= 0.017
# Mejor combinación: 45. Score: 0.016
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0217
# Finalizada combinación 54 de 120. Score= 0.024
# Mejor combinación: 45. Score: 0.016
# 10/10 [==============================] - 0s 10ms/step
# Finalizada combinación 55 de 120. Score= 0.027
# Mejor combinación: 45. Score: 0.016
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 56 de 120. Score= 0.071
# Mejor combinación: 45. Score: 0.016
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 57 de 120. Score= 0.018
# Mejor combinación: 45. Score: 0.016
# 10/10 [==============================] - 0s 892us/step
# Finalizada combinación 58 de 120. Score= 0.022
# Mejor combinación: 45. Score: 0.016
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 59 de 120. Score= 0.017
# Mejor combinación: 45. Score: 0.016
# 10/10 [==============================] - 0s 1ms/step
# Finalizada combinación 60 de 120. Score= 0.023
# Mejor combinación: 45. Score: 0.016
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0225
# Finalizada combinación 61 de 120. Score= 0.019
# Mejor combinación: 45. Score: 0.016
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0562
# Finalizada combinación 62 de 120. Score= 0.06
# Mejor combinación: 45. Score: 0.016
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0235
# Finalizada combinación 63 de 120. Score= 0.016
# Mejor combinación: 45. Score: 0.016
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0206
# Finalizada combinación 64 de 120. Score= 0.024
# Mejor combinación: 45. Score: 0.016
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0160
# Finalizada combinación 65 de 120. Score= 0.017
# Mejor combinación: 45. Score: 0.016
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0168
# Finalizada combinación 66 de 120. Score= 0.024
# Mejor combinación: 45. Score: 0.016
# 10/10 [==============================] - 1s 9ms/step
# Finalizada combinación 67 de 120. Score= 0.022
# Mejor combinación: 45. Score: 0.016
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 68 de 120. Score= 0.082
# Mejor combinación: 45. Score: 0.016
# 10/10 [==============================] - 0s 3ms/step
# Finalizada combinación 69 de 120. Score= 0.016
# Mejor combinación: 69. Score: 0.016
# 10/10 [==============================] - 1s 29ms/step
# Finalizada combinación 70 de 120. Score= 0.023
# Mejor combinación: 69. Score: 0.016
# 10/10 [==============================] - 1s 4ms/step
# Finalizada combinación 71 de 120. Score= 0.015
# Mejor combinación: 71. Score: 0.015
# 10/10 [==============================] - 1s 28ms/step
# Finalizada combinación 72 de 120. Score= 0.026
# Mejor combinación: 71. Score: 0.015
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0192
# Finalizada combinación 73 de 120. Score= 0.022
# Mejor combinación: 71. Score: 0.015
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0320
# Finalizada combinación 74 de 120. Score= 0.056
# Mejor combinación: 71. Score: 0.015
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0239
# Finalizada combinación 75 de 120. Score= 0.02
# Mejor combinación: 71. Score: 0.015
# 10/10 [==============================] - 0s 860us/step - loss: 0.0200
# Finalizada combinación 76 de 120. Score= 0.022
# Mejor combinación: 71. Score: 0.015
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0167
# Finalizada combinación 77 de 120. Score= 0.017
# Mejor combinación: 71. Score: 0.015
# 10/10 [==============================] - 0s 617us/step - loss: 0.0201
# Finalizada combinación 78 de 120. Score= 0.023
# Mejor combinación: 71. Score: 0.015
# 10/10 [==============================] - 0s 797us/step
# Finalizada combinación 79 de 120. Score= 0.018
# Mejor combinación: 71. Score: 0.015
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 80 de 120. Score= 0.066
# Mejor combinación: 71. Score: 0.015
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 81 de 120. Score= 0.018
# Mejor combinación: 71. Score: 0.015
# 10/10 [==============================] - 0s 4ms/step
# Finalizada combinación 82 de 120. Score= 0.022
# Mejor combinación: 71. Score: 0.015
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 83 de 120. Score= 0.017
# Mejor combinación: 71. Score: 0.015
# 10/10 [==============================] - 0s 6ms/step
# Finalizada combinación 84 de 120. Score= 0.023
# Mejor combinación: 71. Score: 0.015
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0400
# Finalizada combinación 85 de 120. Score= 0.02
# Mejor combinación: 71. Score: 0.015
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0195
# Finalizada combinación 86 de 120. Score= 0.057
# Mejor combinación: 71. Score: 0.015
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0227
# Finalizada combinación 87 de 120. Score= 0.02
# Mejor combinación: 71. Score: 0.015
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0227
# Finalizada combinación 88 de 120. Score= 0.022
# Mejor combinación: 71. Score: 0.015
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0213
# Finalizada combinación 89 de 120. Score= 0.018
# Mejor combinación: 71. Score: 0.015
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0207
# Finalizada combinación 90 de 120. Score= 0.023
# Mejor combinación: 71. Score: 0.015
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 91 de 120. Score= 0.029
# Mejor combinación: 71. Score: 0.015
# 10/10 [==============================] - 0s 4ms/step
# Finalizada combinación 92 de 120. Score= 0.074
# Mejor combinación: 71. Score: 0.015
# 10/10 [==============================] - 0s 4ms/step
# Finalizada combinación 93 de 120. Score= 0.018
# Mejor combinación: 71. Score: 0.015
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 94 de 120. Score= 0.022
# Mejor combinación: 71. Score: 0.015
# 10/10 [==============================] - 0s 3ms/step
# Finalizada combinación 95 de 120. Score= 0.02
# Mejor combinación: 71. Score: 0.015
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 96 de 120. Score= 0.024
# Mejor combinación: 71. Score: 0.015
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0186
# Finalizada combinación 97 de 120. Score= 0.018
# Mejor combinación: 71. Score: 0.015
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0654
# Finalizada combinación 98 de 120. Score= 0.064
# Mejor combinación: 71. Score: 0.015
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0225
# Finalizada combinación 99 de 120. Score= 0.019
# Mejor combinación: 71. Score: 0.015
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0183
# Finalizada combinación 100 de 120. Score= 0.021
# Mejor combinación: 71. Score: 0.015
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0185
# Finalizada combinación 101 de 120. Score= 0.017
# Mejor combinación: 71. Score: 0.015
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0198
# Finalizada combinación 102 de 120. Score= 0.023
# Mejor combinación: 71. Score: 0.015
# 9/9 [==============================] - 0s 2ms/step
# Finalizada combinación 103 de 120. Score= 0.018
# Mejor combinación: 71. Score: 0.015
# 9/9 [==============================] - 0s 2ms/step
# Finalizada combinación 104 de 120. Score= 0.069
# Mejor combinación: 71. Score: 0.015
# 9/9 [==============================] - 0s 0s/step
# Finalizada combinación 105 de 120. Score= 0.02
# Mejor combinación: 71. Score: 0.015
# 9/9 [==============================] - 0s 12ms/step
# Finalizada combinación 106 de 120. Score= 0.022
# Mejor combinación: 71. Score: 0.015
# 9/9 [==============================] - 0s 1ms/step
# Finalizada combinación 107 de 120. Score= 0.018
# Mejor combinación: 71. Score: 0.015
# 9/9 [==============================] - 0s 2ms/step
# Finalizada combinación 108 de 120. Score= 0.022
# Mejor combinación: 71. Score: 0.015
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0201
# Finalizada combinación 109 de 120. Score= 0.02
# Mejor combinación: 71. Score: 0.015
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0432
# Finalizada combinación 110 de 120. Score= 0.064
# Mejor combinación: 71. Score: 0.015
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0269
# Finalizada combinación 111 de 120. Score= 0.02
# Mejor combinación: 71. Score: 0.015
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0201
# Finalizada combinación 112 de 120. Score= 0.022
# Mejor combinación: 71. Score: 0.015
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0198
# Finalizada combinación 113 de 120. Score= 0.016
# Mejor combinación: 71. Score: 0.015
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0163
# Finalizada combinación 114 de 120. Score= 0.022
# Mejor combinación: 71. Score: 0.015
# 9/9 [==============================] - 0s 480us/step
# Finalizada combinación 115 de 120. Score= 0.018
# Mejor combinación: 71. Score: 0.015
# 9/9 [==============================] - 0s 243us/step
# Finalizada combinación 116 de 120. Score= 0.071
# Mejor combinación: 71. Score: 0.015
# 9/9 [==============================] - 0s 2ms/step
# Finalizada combinación 117 de 120. Score= 0.018
# Mejor combinación: 71. Score: 0.015
# 9/9 [==============================] - 0s 2ms/step
# Finalizada combinación 118 de 120. Score= 0.022
# Mejor combinación: 71. Score: 0.015
# 9/9 [==============================] - 0s 3ms/step
# Finalizada combinación 119 de 120. Score= 0.015
# Mejor combinación: 119. Score: 0.015
# 9/9 [==============================] - 0s 1ms/step
# Finalizada combinación 120 de 120. Score= 0.024
# Mejor combinación: 119. Score: 0.015

# %%
df_eval.sort_values(by='cv_scores_mean')
# Out:
#      combinacion  nro_pasos  nro_capas_lstm unidades_capa loss_function  \
# 118          119          5               2        50, 30           mae
# 70            71          3               2        50, 30           mae
# 68            69          3               2        50, 30           mae
# 44            45          2               2        50, 30           mae
# 62            63          3               2        50, 30           mse
# ..           ...        ...             ...           ...           ...
# 91            92          4               2        50, 30           mae
# 19            20          1               2        50, 30           mae
# 13            14          1               2        50, 30           mse
# 1              2          1               1            50           mse
# 67            68          3               2        50, 30           mae
#
#     act_salida act_lstm  loss_value(mse)  cv_scores_mean  tiempo(s)
# 118    sigmoid     relu         0.017869        0.015131  41.797293
# 70     sigmoid     relu         0.012675        0.015171  86.127129
# 68      linear     relu         0.016570        0.016047  34.487502
# 44      linear     relu         0.019642        0.016110  30.804859
# 62      linear     relu         0.023532        0.016142  90.362791
# ..         ...      ...              ...             ...        ...
# 91        relu  sigmoid         0.033887        0.073573  44.357676
# 19        relu  sigmoid         0.076828        0.075975  29.491852
# 13        relu  sigmoid         0.080380        0.076606  28.125607
# 1         relu  sigmoid         0.055517        0.077681  18.081091
# 67        relu  sigmoid         0.019947        0.082004  61.604644
#
# [120 rows x 10 columns]

# %% [markdown]
# Construyamos el mejor modelo:

# %%
modelo, scaler_X, scaler_Y, X_test_reshaped, Y_test_reshaped, scores, history, loss = construir_modelo_cv(X, Y, nro_pasos=5, nro_capas_lstm=2, 
                                                                                        unidades_capa=[50, 30], loss_='mae', act_lstm='relu',
                                                                                        act_salida='sigmoid', learning_r=0.0001, epochs=100)
graficar_curva_aprendizaje(history)
# Out:
# 9/9 [==============================] - 0s 2ms/step
# Valor final de Loss: 0.10378260910511017

# %%
graficar_pred_test(X_test_reshaped, Y_test_reshaped, modelo, scaler_Y)
# Out:
# 9/9 [==============================] - 0s 3ms/step

# %% [markdown]
# Bajemos el learning rate y aumentemos las epochs:

# %%
modelo, scaler_X, scaler_Y, X_test_reshaped, Y_test_reshaped, scores, history, loss = construir_modelo_cv(X, Y, nro_pasos=5, nro_capas_lstm=2, 
                                                                                        unidades_capa=[50, 30], loss_='mae', act_lstm='relu',
                                                                                        act_salida='sigmoid', learning_r=0.00001, epochs=150)
graficar_curva_aprendizaje(history)
# Out:
# 9/9 [==============================] - 0s 1ms/step
# Valor final de Loss: 0.13084112107753754

# %%
modelo, scaler_X, scaler_Y, X_test_reshaped, Y_test_reshaped, scores, history, loss = construir_modelo_cv(X, Y, nro_pasos=5, nro_capas_lstm=2, 
                                                                                        unidades_capa=[50, 30], loss_='mae', act_lstm='relu',
                                                                                        act_salida='sigmoid', learning_r=0.0001, epochs=200)
graficar_curva_aprendizaje(history)
# Out:
# 9/9 [==============================] - 0s 1ms/step
# Valor final de Loss: 0.07179346680641174

# %%
graficar_pred_test(X_test_reshaped, Y_test_reshaped, modelo, scaler_Y)
# Out:
# 9/9 [==============================] - 0s 3ms/step

# %% [markdown]
# Agreguemos más neuronas en la segunda capa

# %%
modelo, scaler_X, scaler_Y, X_test_reshaped, Y_test_reshaped, scores, history, loss = construir_modelo_cv(X, Y, nro_pasos=5, nro_capas_lstm=2, 
                                                                                        unidades_capa=[50, 40], loss_='mae', act_lstm='relu',
                                                                                        act_salida='sigmoid', learning_r=0.0001, epochs=200)
graficar_curva_aprendizaje(history)
# Out:
# 9/9 [==============================] - 1s 4ms/step
# Valor final de Loss: 0.07996129244565964

# %%
graficar_pred_test(X_test_reshaped, Y_test_reshaped, modelo, scaler_Y)
# Out:
# 9/9 [==============================] - 0s 2ms/step

# %% [markdown]
# Hagamos una nueva evaluación, solamente variando el número de pasos

# %%
df_eval = evaluar_modelos(X,Y,nro_pasos=25,nro_capas_lstm=[2], unidades_capa=[50,40])
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0188
# Finalizada combinación 1 de 50. Score= 0.019
# Mejor combinación: 1. Score: 0.019
# Quedan 38.02016361157099 minutos.
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 2 de 50. Score= 0.019
# Mejor combinación: 1. Score: 0.019
# Quedan 28.466897678375243 minutos.
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0303
# Finalizada combinación 3 de 50. Score= 0.018
# Mejor combinación: 3. Score: 0.018
# Quedan 26.798246167765726 minutos.
# 10/10 [==============================] - 0s 1ms/step
# Finalizada combinación 4 de 50. Score= 0.017
# Mejor combinación: 4. Score: 0.017
# Quedan 25.7196972767512 minutos.
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0235
# Finalizada combinación 5 de 50. Score= 0.017
# Mejor combinación: 5. Score: 0.017
# Quedan 25.122785460948943 minutos.
# 10/10 [==============================] - 0s 1ms/step
# Finalizada combinación 6 de 50. Score= 0.018
# Mejor combinación: 5. Score: 0.017
# Quedan 24.530370375845166 minutos.
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0200
# Finalizada combinación 7 de 50. Score= 0.02
# Mejor combinación: 5. Score: 0.017
# Quedan 24.588384865011488 minutos.
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 8 de 50. Score= 0.02
# Mejor combinación: 5. Score: 0.017
# Quedan 24.418956443667412 minutos.
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0226
# Finalizada combinación 9 de 50. Score= 0.019
# Mejor combinación: 5. Score: 0.017
# Quedan 24.13215842379464 minutos.
# 9/9 [==============================] - 0s 2ms/step
# Finalizada combinación 10 de 50. Score= 0.018
# Mejor combinación: 5. Score: 0.017
# Quedan 23.859355847040813 minutos.
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0207
# Finalizada combinación 11 de 50. Score= 0.018
# Mejor combinación: 5. Score: 0.017
# Quedan 23.836154369874432 minutos.
# 9/9 [==============================] - 0s 3ms/step
# Finalizada combinación 12 de 50. Score= 0.019
# Mejor combinación: 5. Score: 0.017
# Quedan 23.543767975436317 minutos.
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0328
# Finalizada combinación 13 de 50. Score= 0.022
# Mejor combinación: 5. Score: 0.017
# Quedan 23.69598500117278 minutos.
# 9/9 [==============================] - 0s 2ms/step
# Finalizada combinación 14 de 50. Score= 0.017
# Mejor combinación: 5. Score: 0.017
# Quedan 24.085830106054036 minutos.
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0198
# Finalizada combinación 15 de 50. Score= 0.017
# Mejor combinación: 5. Score: 0.017
# Quedan 24.32663913965225 minutos.
# 9/9 [==============================] - 0s 4ms/step
# Finalizada combinación 16 de 50. Score= 0.019
# Mejor combinación: 5. Score: 0.017
# Quedan 24.22041294525067 minutos.
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0211
# Finalizada combinación 17 de 50. Score= 0.017
# Mejor combinación: 5. Score: 0.017
# Quedan 23.87643391034182 minutos.
# 9/9 [==============================] - 0s 3ms/step
# Finalizada combinación 18 de 50. Score= 0.02
# Mejor combinación: 5. Score: 0.017
# Quedan 23.42224256021005 minutos.
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0182
# Finalizada combinación 19 de 50. Score= 0.017
# Mejor combinación: 5. Score: 0.017
# Quedan 23.061753826392323 minutos.
# 9/9 [==============================] - 0s 3ms/step
# Finalizada combinación 20 de 50. Score= 0.017
# Mejor combinación: 5. Score: 0.017
# Quedan 22.65814565420151 minutos.
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0221
# Finalizada combinación 21 de 50. Score= 0.021
# Mejor combinación: 5. Score: 0.017
# Quedan 22.369754866948202 minutos.
# 9/9 [==============================] - 0s 5ms/step
# Finalizada combinación 22 de 50. Score= 0.023
# Mejor combinación: 5. Score: 0.017
# Quedan 21.86204541090763 minutos.
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0207
# Finalizada combinación 23 de 50. Score= 0.021
# Mejor combinación: 5. Score: 0.017
# Quedan 21.36891165608945 minutos.
# 9/9 [==============================] - 0s 9ms/step
# Finalizada combinación 24 de 50. Score= 0.018
# Mejor combinación: 5. Score: 0.017
# Quedan 20.862226325273515 minutos.
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0212
# Finalizada combinación 25 de 50. Score= 0.018
# Mejor combinación: 5. Score: 0.017
# Quedan 20.356501948833465 minutos.
# 9/9 [==============================] - 0s 4ms/step
# Finalizada combinación 26 de 50. Score= 0.027
# Mejor combinación: 5. Score: 0.017
# Quedan 19.841349645761344 minutos.
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0188
# Finalizada combinación 27 de 50. Score= 0.021
# Mejor combinación: 5. Score: 0.017
# Quedan 19.286449346277447 minutos.
# 9/9 [==============================] - 0s 6ms/step
# Finalizada combinación 28 de 50. Score= 0.035
# Mejor combinación: 5. Score: 0.017
# Quedan 18.727323494354884 minutos.
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0220
# Finalizada combinación 29 de 50. Score= 0.023
# Mejor combinación: 5. Score: 0.017
# Quedan 19.342370378148967 minutos.
# 9/9 [==============================] - 1s 17ms/step
# Finalizada combinación 30 de 50. Score= 0.022
# Mejor combinación: 5. Score: 0.017
# Quedan 20.044453059302437 minutos.
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0229
# Finalizada combinación 31 de 50. Score= 0.025
# Mejor combinación: 5. Score: 0.017
# Quedan 20.586486265864423 minutos.
# 9/9 [==============================] - 1s 11ms/step
# Finalizada combinación 32 de 50. Score= 0.022
# Mejor combinación: 5. Score: 0.017
# Quedan 21.01468323469162 minutos.
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0310
# Finalizada combinación 33 de 50. Score= 0.022
# Mejor combinación: 5. Score: 0.017
# Quedan 20.92808085643884 minutos.
# 9/9 [==============================] - 1s 16ms/step
# Finalizada combinación 34 de 50. Score= 0.02
# Mejor combinación: 5. Score: 0.017
# Quedan 20.75574208427878 minutos.
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0276
# Finalizada combinación 35 de 50. Score= 0.018
# Mejor combinación: 5. Score: 0.017
# Quedan 20.448573420728955 minutos.
# 9/9 [==============================] - 1s 18ms/step
# Finalizada combinación 36 de 50. Score= 0.02
# Mejor combinación: 5. Score: 0.017
# Quedan 19.972401414535664 minutos.
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0219
# Finalizada combinación 37 de 50. Score= 0.022
# Mejor combinación: 5. Score: 0.017
# Quedan 19.124894971353513 minutos.
# 9/9 [==============================] - 1s 16ms/step
# Finalizada combinación 38 de 50. Score= 0.019
# Mejor combinación: 5. Score: 0.017
# Quedan 18.1672947632639 minutos.
# 9/9 [==============================] - 0s 18ms/step - loss: 0.0226
# Finalizada combinación 39 de 50. Score= 0.019
# Mejor combinación: 5. Score: 0.017
# Quedan 17.495251305286704 minutos.
# 9/9 [==============================] - 1s 19ms/step
# Finalizada combinación 40 de 50. Score= 0.041
# Mejor combinación: 5. Score: 0.017
# Quedan 16.289367679754893 minutos.
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0289
# Finalizada combinación 41 de 50. Score= 0.026
# Mejor combinación: 5. Score: 0.017
# Quedan 14.95238411891751 minutos.
# 9/9 [==============================] - 1s 15ms/step
# Finalizada combinación 42 de 50. Score= 0.024
# Mejor combinación: 5. Score: 0.017
# Quedan 13.319521067634462 minutos.
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0248
# Finalizada combinación 43 de 50. Score= 0.024
# Mejor combinación: 5. Score: 0.017
# Quedan 11.711047634782718 minutos.
# 9/9 [==============================] - 0s 6ms/step
# Finalizada combinación 44 de 50. Score= 0.019
# Mejor combinación: 5. Score: 0.017
# Quedan 10.07070228728381 minutos.
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0188
# Finalizada combinación 45 de 50. Score= 0.023
# Mejor combinación: 5. Score: 0.017
# Quedan 8.438366459034107 minutos.
# 9/9 [==============================] - 1s 8ms/step
# Finalizada combinación 46 de 50. Score= 0.018
# Mejor combinación: 5. Score: 0.017
# Quedan 6.792857516330221 minutos.
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0265
# Finalizada combinación 47 de 50. Score= 0.02
# Mejor combinación: 5. Score: 0.017
# Quedan 5.118883616873559 minutos.
# 9/9 [==============================] - 1s 14ms/step
# Finalizada combinación 48 de 50. Score= 0.019
# Mejor combinación: 5. Score: 0.017
# Quedan 3.465843202670415 minutos.
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0217
# Finalizada combinación 49 de 50. Score= 0.018
# Mejor combinación: 5. Score: 0.017
# Quedan 1.7400073975121895 minutos.
# 9/9 [==============================] - 0s 7ms/step
# Finalizada combinación 50 de 50. Score= 0.024
# Mejor combinación: 5. Score: 0.017
# Quedan 0.0 minutos.

# %%
df_eval.sort_values(by='cv_scores_mean')
# Out:
#     combinacion  nro_pasos  nro_capas_lstm unidades_capa loss_function  \
# 4             5          3               2        50, 40           mse
# 19           20         10               2        50, 40           mae
# 18           19         10               2        50, 40           mse
# 3             4          2               2        50, 40           mae
# 16           17          9               2        50, 40           mse
# 14           15          8               2        50, 40           mse
# 13           14          7               2        50, 40           mae
# 5             6          3               2        50, 40           mae
# 9            10          5               2        50, 40           mae
# 45           46         23               2        50, 40           mae
# 23           24         12               2        50, 40           mae
# 2             3          2               2        50, 40           mse
# 48           49         25               2        50, 40           mse
# 10           11          6               2        50, 40           mse
# 24           25         13               2        50, 40           mse
# 34           35         18               2        50, 40           mse
# 0             1          1               2        50, 40           mse
# 43           44         22               2        50, 40           mae
# 11           12          6               2        50, 40           mae
# 38           39         20               2        50, 40           mse
# 1             2          1               2        50, 40           mae
# 37           38         19               2        50, 40           mae
# 15           16          8               2        50, 40           mae
# 8             9          5               2        50, 40           mse
# 47           48         24               2        50, 40           mae
# 33           34         17               2        50, 40           mae
# 17           18          9               2        50, 40           mae
# 35           36         18               2        50, 40           mae
# 46           47         24               2        50, 40           mse
# 7             8          4               2        50, 40           mae
# 6             7          4               2        50, 40           mse
# 20           21         11               2        50, 40           mse
# 26           27         14               2        50, 40           mse
# 22           23         12               2        50, 40           mse
# 36           37         19               2        50, 40           mse
# 32           33         17               2        50, 40           mse
# 31           32         16               2        50, 40           mae
# 29           30         15               2        50, 40           mae
# 12           13          7               2        50, 40           mse
# 44           45         23               2        50, 40           mse
# 28           29         15               2        50, 40           mse
# 21           22         11               2        50, 40           mae
# 49           50         25               2        50, 40           mae
# 41           42         21               2        50, 40           mae
# 42           43         22               2        50, 40           mse
# 30           31         16               2        50, 40           mse
# 40           41         21               2        50, 40           mse
# 25           26         13               2        50, 40           mae
# 27           28         14               2        50, 40           mae
# 39           40         20               2        50, 40           mae
#
#    act_salida act_lstm  loss_value(mse)  cv_scores_mean   tiempo(s)
# 4      linear     relu         0.023494        0.016743   33.295511
# 19     linear     relu         0.018315        0.016911   58.248427
# 18     linear     relu         0.018177        0.017044   57.576712
# 3      linear     relu         0.018809        0.017152   31.558144
# 16     linear     relu         0.021064        0.017274   54.128383
# 14     linear     relu         0.019839        0.017284   63.539447
# 13     linear     relu         0.015655        0.017456   62.465721
# 5      linear     relu         0.017320        0.017753   33.217794
# 9      linear     relu         0.021442        0.017829   40.052154
# 45     linear     relu         0.021925        0.018024  130.353798
# 23     linear     relu         0.024224        0.018173   63.257563
# 2      linear     relu         0.030347        0.018220   31.464337
# 48     linear     relu         0.021664        0.018388  124.807537
# 10     linear     relu         0.020702        0.018395   45.490736
# 24     linear     relu         0.021159        0.018451   65.943736
# 34     linear     relu         0.027619        0.018493  216.443163
# 0      linear     relu         0.018768        0.018520   46.555302
# 43     linear     relu         0.016914        0.018633  114.751450
# 11     linear     relu         0.023194        0.018672   42.711372
# 38     linear     relu         0.022552        0.018736  269.931091
# 1      linear     relu         0.016269        0.018836   24.611942
# 37     linear     relu         0.023904        0.018839  185.842402
# 15     linear     relu         0.021602        0.018860   58.328334
# 8      linear     relu         0.022576        0.019026   38.764396
# 47     linear     relu         0.025491        0.019390  179.063612
# 33     linear     relu         0.019664        0.019624  208.851228
# 17     linear     relu         0.016565        0.019904   52.501820
# 35     linear     relu         0.029965        0.020221  218.655939
# 46     linear     relu         0.026513        0.020371  124.678914
# 7      linear     relu         0.015505        0.020380   38.908168
# 6      linear     relu         0.019976        0.020472   39.462589
# 20     linear     relu         0.022063        0.020582   65.601454
# 26     linear     relu         0.018818        0.020942   68.749140
# 22     linear     relu         0.020733        0.021377   61.549534
# 36     linear     relu         0.021938        0.021907  184.487385
# 32     linear     relu         0.030974        0.022026  195.939676
# 31     linear     relu         0.022125        0.022048  226.257556
# 29     linear     relu         0.020304        0.022093  201.347230
# 12     linear     relu         0.032824        0.022287   53.444535
# 44     linear     relu         0.018772        0.022759  125.608881
# 28     linear     relu         0.022045        0.022878  172.567024
# 21     linear     relu         0.015129        0.023215   58.712003
# 49     linear     relu         0.022315        0.023519  101.173942
# 41     linear     relu         0.026448        0.023571  108.664144
# 42     linear     relu         0.024813        0.024147  120.708421
# 30     linear     relu         0.022891        0.025038  211.307880
# 40     linear     relu         0.028921        0.026211  177.536749
# 25     linear     relu         0.020446        0.027461   68.297610
# 27     linear     relu         0.025953        0.034766   71.649654
# 39     linear     relu         0.028424        0.041217  187.731147

# %%
modelo, scaler_X, scaler_Y, X_test_reshaped, Y_test_reshaped, scores, history, loss = construir_modelo_cv(X, Y, nro_pasos=3, nro_capas_lstm=2, 
                                                                                        unidades_capa=[50, 40], loss_='mse', act_lstm='relu',
                                                                                        act_salida='linear', learning_r=0.0001, epochs=200)
graficar_curva_aprendizaje(history)
# Out:
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0197
# Valor final de Loss: 0.019656546413898468

# %%
graficar_pred_test(X_test_reshaped, Y_test_reshaped, modelo, scaler_Y)
# Out:
# 10/10 [==============================] - 1s 5ms/step

# %% [markdown]
# Probemos agregando mas capas dense:

# %%
df_eval = evaluar_modelos(X,Y,nro_pasos=2,nro_capas_lstm=[2], unidades_capa=[50,40], nro_capas_dense=1, unidades_dense=[40])
# Out:
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0258
# Finalizada combinación 1 de 4. Score= 0.018
# Mejor combinación: 1. Score: 0.018
# Quedan 1.4 minutos.
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 2 de 4. Score= 0.019
# Mejor combinación: 1. Score: 0.018
# Quedan 1.56 minutos.
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0185
# Finalizada combinación 3 de 4. Score= 0.017
# Mejor combinación: 3. Score: 0.017
# Quedan 0.74 minutos.
# 10/10 [==============================] - 0s 2ms/step
# Finalizada combinación 4 de 4. Score= 0.017
# Mejor combinación: 4. Score: 0.017
# Quedan 0.0 minutos.

# %%
df_eval
# Out:
#    combinacion  nro_pasos  nro_capas_lstm unidades_capa  nro_capas_dense  \
# 0            1          1               2        50, 40                1
# 1            2          1               2        50, 40                1
# 2            3          2               2        50, 40                1
# 3            4          2               2        50, 40                1
#
#   unidades_dense loss_function act_salida act_lstm act_dense  loss_value(mse)  \
# 0             40           mse     linear     relu    linear         0.025830
# 1             40           mae     linear     relu    linear         0.018313
# 2             40           mse     linear     relu    linear         0.018466
# 3             40           mae     linear     relu    linear         0.018114
#
#    cv_scores_mean  tiempo(s)
# 0        0.017901  27.990340
# 1        0.018816  65.537866
# 2        0.017356  39.701928
# 3        0.016864  38.905261

# %%
df_eval.sort_values(by='cv_scores_mean')
# Out:
#    combinacion  nro_pasos  nro_capas_lstm unidades_capa  nro_capas_dense  \
# 3            4          2               2        50, 40                1
# 2            3          2               2        50, 40                1
# 0            1          1               2        50, 40                1
# 1            2          1               2        50, 40                1
#
#   unidades_dense loss_function act_salida act_lstm act_dense  loss_value(mse)  \
# 3             40           mae     linear     relu    linear         0.018114
# 2             40           mse     linear     relu    linear         0.018466
# 0             40           mse     linear     relu    linear         0.025830
# 1             40           mae     linear     relu    linear         0.018313
#
#    cv_scores_mean  tiempo(s)
# 3        0.016864  38.905261
# 2        0.017356  39.701928
# 0        0.017901  27.990340
# 1        0.018816  65.537866

# %% [markdown]
# Ya vemos que las modificaciones funcionan.
