# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.utils import plot_model
# Out:
# WARNING:tensorflow:From c:\Users\alter\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# Cargamos los datos a modelar. Inicialmente probaremos modelos sólo con 2 meses (noviembre y diciembre 2023).

# %%
df = pd.read_parquet('data_export/prueba_ml.parquet')
df.head()
# Out:
#        fecha  hora  temperature_2m  rain  relative_humidity_2m  snowfall  \
# 3 2023-11-01   0.0          8.6725   0.1             60.153034       0.0
# 4 2023-11-01   1.0          8.5725   0.0             60.344471       0.0
# 5 2023-11-01   2.0          8.3225   0.1             62.933163       0.0
# 6 2023-11-01   3.0          8.0725   0.0             66.100021       0.0
# 7 2023-11-01   4.0          7.7725   0.0             72.938622       0.0
#
#    Bronx  Brooklyn  Manhattan  Queens  Staten Island   año  mes  dia
# 3      3        12       2196     232              1  2023   11    1
# 4      2        12       1521      55              0  2023   11    1
# 5      3         8       1214      16              0  2023   11    1
# 6      0        13        854      20              0  2023   11    1
# 7     12        20        654      25              0  2023   11    1

# %%
df.reset_index(inplace=True, drop=True)

# %%
columnas_X = ['año', 'mes', 'dia', 'hora', 'temperature_2m', 'rain', 'relative_humidity_2m', 'snowfall']
X = df[columnas_X]

columnas_Y = ['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island']
Y = df[columnas_Y]

# %% [markdown]
# Grafiquemos para ver como es la demanda:

# %%
for i in columnas_Y:
    sns.lineplot(x=df.index, y=df[i], label=i)
    plt.legend()
    plt.show()

# %% [markdown]
# Definamos una función que retorna los arrays de X e Y con la forma que requiere la entrada a la capa  LSTM

# %%
def generador_X_Y(X, Y, p):
    ''' 
    A partir dos dataframes, X e Y, y los pasos de tiempo, retorna un tensor 3D para X y una array 2D para Y.
    args:
    - X: pandas dataframe, con m filas (muestras) y n columnas (features)
    - Y: pandas dataframe, con m filas (muestras) e y columnas (longitud de vector de respuesta)
    - p (int): número de pasos de tiempo a considerar
    returns:
    - X_reshaped: numpy array de forma (m, p, n)
    - Y_reshaped: numpy array de forma (m, y)
    '''
    
    X_reshaped_list = list()
    Y_rehaped_list = list()

    m = len(X)
    X = np.array(X)
    Y = np.array(Y)

    for i in range(m-p):
        X_reshaped_list.append(X[i:i+p, :])
        Y_rehaped_list.append(Y[i+p, :])
    
    X_reshaped = np.array(X_reshaped_list)
    Y_reshaped = np.array(Y_rehaped_list)

    return X_reshaped, Y_reshaped

# %% [markdown]
# Veamos las shape iniciales:

# %%
print('Shape de X:', X.shape)
print('Shape de Y:', Y.shape)
# Out:
# Shape de X: (1464, 8)
# Shape de Y: (1464, 5)

# %% [markdown]
# Vemos que tanto X como Y tienen 1464 muestras, X tiene 8 features, e Y contiene vectores de 5 componentes (la demanda para cada distrito).

# %% [markdown]
# Hagamos una primera prueba de LSTM

# %%
# Normalizar los datos
scaler_X = MinMaxScaler()
scaler_Y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
Y_scaled = scaler_Y.fit_transform(Y)

# Generamos listas vacías para almacenar datos
lista_loss = []
lista_pasos = []

# Dividimos los datos en conjuntos de entrenamiento y prueba
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y_scaled, test_size=0.2, shuffle=False)

for pasos in range(1,25):

    # Reshape de los datos para que sean 3D (número de muestras, número de pasos de tiempo, número de características)
    X_train_reshaped, Y_train_reshaped = generador_X_Y(X_train, Y_train, pasos)
    X_test_reshaped, Y_test_reshaped = generador_X_Y(X_test, Y_test, pasos)

    # Construimos el modelo LSTM
    model = Sequential()
    model.add(LSTM(units=50, activation='relu', input_shape=(X_train_reshaped.shape[1], X_train_reshaped.shape[2])))
    model.add(Dense(units=Y_train_reshaped.shape[1]))  # Capa de salida con tantas neuronas como variables de salida
    model.compile(optimizer='adam', loss='mse')  # Compilación del modelo

    #model.summary()

    # Entrenar el modelo
    model.fit(X_train_reshaped, Y_train_reshaped, epochs=50, batch_size=32, validation_data=(X_test_reshaped, Y_test_reshaped), verbose=0)

    # Evaluación del modelo
    loss = model.evaluate(X_test_reshaped, Y_test_reshaped)
    print('Número de pasos',pasos ,'Loss (MSE):', loss)
    lista_pasos.append(pasos)
    lista_loss.append(loss)

sns.lineplot(x= lista_pasos, y=lista_loss)
plt.xlabel('Número de pasos')
plt.ylabel('Loss')
plt.show()
# Out:
# WARNING:tensorflow:From c:\Users\alter\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\alter\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From c:\Users\alter\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0232
# Número de pasos 1 Loss (MSE): 0.023173408582806587
# 10/10 [==============================] - 0s 679us/step - loss: 0.0272
# Número de pasos 2 Loss (MSE): 0.027217291295528412
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0199
# Número de pasos 3 Loss (MSE): 0.01989796571433544
# 10/10 [==============================] - 0s 295us/step - loss: 0.0253
# Número de pasos 4 Loss (MSE): 0.025324072688817978
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0161
# Número de pasos 5 Loss (MSE): 0.016118435189127922
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0253
# Número de pasos 6 Loss (MSE): 0.025250447914004326
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0177
# Número de pasos 7 Loss (MSE): 0.01773245818912983
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0239
# Número de pasos 8 Loss (MSE): 0.023930711671710014
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0303
# Número de pasos 9 Loss (MSE): 0.030283940955996513
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0246
# Número de pasos 10 Loss (MSE): 0.02461322955787182
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0192
# Número de pasos 11 Loss (MSE): 0.019229255616664886
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0334
# Número de pasos 12 Loss (MSE): 0.033373378217220306
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0279
# Número de pasos 13 Loss (MSE): 0.027917923405766487
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0246
# Número de pasos 14 Loss (MSE): 0.024586087092757225
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0316
# Número de pasos 15 Loss (MSE): 0.031636834144592285
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0274
# Número de pasos 16 Loss (MSE): 0.027449654415249825
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0169
# Número de pasos 17 Loss (MSE): 0.0168851800262928
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0319
# Número de pasos 18 Loss (MSE): 0.031940024346113205
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0399
# Número de pasos 19 Loss (MSE): 0.039864521473646164
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0320
# Número de pasos 20 Loss (MSE): 0.03200807422399521
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0341
# Número de pasos 21 Loss (MSE): 0.03409670665860176
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0304
# Número de pasos 22 Loss (MSE): 0.030423888936638832
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0213
# Número de pasos 23 Loss (MSE): 0.021255578845739365
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0349
# Número de pasos 24 Loss (MSE): 0.034911055117845535

# %% [markdown]
# Vemos que hay un mínimo en 5 numero de pasos, es decir, las predicciones toman en cuenta la demanda las 10 horas anteriores. <br>
# Veamos ese modelo en particular:

# %%
# Normalizamos los datos
scaler_X = MinMaxScaler()
scaler_Y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
Y_scaled = scaler_Y.fit_transform(Y)

# Dividimos los datos en conjuntos de entrenamiento y prueba
X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y_scaled, test_size=0.2, shuffle=False)

# Reshape de los datos para que sean 3D (número de muestras, número de pasos de tiempo, número de características)
X_train_reshaped, Y_train_reshaped = generador_X_Y(X_train, Y_train, 5)
X_test_reshaped, Y_test_reshaped = generador_X_Y(X_test, Y_test, 5)

# Construimos el modelo LSTM
model = Sequential()
model.add(LSTM(units=50, activation='relu', input_shape=(X_train_reshaped.shape[1], X_train_reshaped.shape[2])))
model.add(Dense(units=Y_train_reshaped.shape[1]))  # Capa de salida con tantas neuronas como variables de salida
model.compile(optimizer='adam', loss='mse')  # Compilación del modelo

# Entrenamos el modelo y guardamos el historial de entrenamiento
history = model.fit(X_train_reshaped, Y_train_reshaped, epochs=50, batch_size=32, validation_data=(X_test_reshaped, Y_test_reshaped), verbose=1)

# Extraemos los valores de la función de pérdida del historial de entrenamiento
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Graficamos la curva de aprendizaje
plt.plot(train_loss, label='Train Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Curva de Aprendizaje')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 37/37 [==============================] - 1s 8ms/step - loss: 0.0807 - val_loss: 0.0562
# Epoch 2/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0345 - val_loss: 0.0544
# Epoch 3/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0305 - val_loss: 0.0485
# Epoch 4/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0275 - val_loss: 0.0379
# Epoch 5/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0245 - val_loss: 0.0356
# Epoch 6/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0209 - val_loss: 0.0380
# Epoch 7/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0175 - val_loss: 0.0318
# Epoch 8/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0151 - val_loss: 0.0318
# Epoch 9/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0138 - val_loss: 0.0227
# Epoch 10/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0130 - val_loss: 0.0277
# Epoch 11/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0125 - val_loss: 0.0225
# Epoch 12/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0122 - val_loss: 0.0257
# Epoch 13/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0121 - val_loss: 0.0246
# Epoch 14/50
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0116 - val_loss: 0.0292
# Epoch 15/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0114 - val_loss: 0.0284
# Epoch 16/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0113 - val_loss: 0.0242
# Epoch 17/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0110 - val_loss: 0.0224
# Epoch 18/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0112 - val_loss: 0.0178
# Epoch 19/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0110 - val_loss: 0.0217
# Epoch 20/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0108 - val_loss: 0.0207
# Epoch 21/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0108 - val_loss: 0.0213
# Epoch 22/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0104 - val_loss: 0.0198
# Epoch 23/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0104 - val_loss: 0.0231
# Epoch 24/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0103 - val_loss: 0.0207
# Epoch 25/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0104 - val_loss: 0.0196
# Epoch 26/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0102 - val_loss: 0.0193
# Epoch 27/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0102 - val_loss: 0.0186
# Epoch 28/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0105 - val_loss: 0.0207
# Epoch 29/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0101 - val_loss: 0.0236
# Epoch 30/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0103 - val_loss: 0.0201
# Epoch 31/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0102 - val_loss: 0.0197
# Epoch 32/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0104 - val_loss: 0.0196
# Epoch 33/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0100 - val_loss: 0.0263
# Epoch 34/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0099 - val_loss: 0.0224
# Epoch 35/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0100 - val_loss: 0.0254
# Epoch 36/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0098 - val_loss: 0.0250
# Epoch 37/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0100 - val_loss: 0.0220
# Epoch 38/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0100 - val_loss: 0.0180
# Epoch 39/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0097 - val_loss: 0.0183
# Epoch 40/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0098 - val_loss: 0.0211
# Epoch 41/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0097 - val_loss: 0.0174
# Epoch 42/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0098 - val_loss: 0.0179
# Epoch 43/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0098 - val_loss: 0.0200
# Epoch 44/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0096 - val_loss: 0.0208
# Epoch 45/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0095 - val_loss: 0.0239
# Epoch 46/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0097 - val_loss: 0.0225
# Epoch 47/50
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0095 - val_loss: 0.0187
# Epoch 48/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0204
# Epoch 49/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0095 - val_loss: 0.0244
# Epoch 50/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0094 - val_loss: 0.0195

# %%
def graficar_pred_test(X_test_reshaped, Y_test_reshaped, modelo, scaler_Y):
    Y_test_df = pd.DataFrame(Y_test_reshaped, columns=columnas_Y)
    Y_test_original = scaler_Y.inverse_transform(Y_test_df)
    Y_test_original_df = pd.DataFrame(Y_test_original, columns=columnas_Y)

    Y_predict = modelo.predict(X_test_reshaped)
    Y_predict_df = pd.DataFrame(Y_predict, columns=columnas_Y)
    Y_predict_original = scaler_Y.inverse_transform(Y_predict_df)
    Y_predict_original_df = pd.DataFrame(Y_predict_original, columns=columnas_Y)

    for i in columnas_Y:
        sns.lineplot(x=Y_predict_original_df.index, y=Y_predict_original_df[i], label='Predicción')
        sns.lineplot(x=Y_test_original_df.index, y=Y_test_original_df[i], label= 'Real')
        plt.xticks(rotation=45)
        plt.legend()
        plt.show()

# %%
graficar_pred_test(X_test_reshaped, Y_test_reshaped)
# Out:
# 9/9 [==============================] - 0s 1ms/step

# %% [markdown]
# Vemos que hay mucho error en las predicciones. Vamos a replantear el modelo de la siguiente manera: <br>
# Sea 'p' el número de pasos de tiempo a utilizar. <br>
# Para predecir la demanda al tiempo t, se utilizarán los valores de las variables X al tiempo t, t-1, t-2, ..., t-p y la demanda (Y) en los tiempos t-p, t-p+1, ..., t-1. <br>
# Para ello tenemos que reconfigurar las variables de entrada del modelo.

# %%
def generador_X_Y_lag(X, Y, p):
    ''' 
    A partir dos dataframes, X e Y, y los pasos de tiempo, retorna un tensor 3D para X y una array 2D para Y.
    args:
    - X: pandas dataframe, con m filas (muestras) y n columnas (features)
    - Y: pandas dataframe, con m filas (muestras) e y columnas (longitud de vector de respuesta)
    - p (int): número de pasos de tiempo a considerar
    returns:
    - X_reshaped: numpy array de forma (m, p, n+p)
    - Y_reshaped: numpy array de forma (m, y)
    '''
    
    X_reshaped_list = list()
    #Y_rehaped_list = list()

    X = pd.DataFrame(X)
    Y = pd.DataFrame(Y)

    for i in range(1, p+1):
        X = pd.concat([X, Y.shift(i)], axis=1)      # agrega la demanda de la hora i anterior

    X.dropna(how='any', inplace=True)
    Y = Y.iloc[2*p-1:-1,:]
    
    m = len(X)
    X = np.array(X)
    Y = np.array(Y)

    for i in range(m-p):
        X_reshaped_list.append(X[i:i+p, :])
        #Y_rehaped_list.append(Y[i+p, :])
    
    X_reshaped = np.array(X_reshaped_list)
    Y_reshaped = np.array(Y)

    return X_reshaped, Y_reshaped

# %% [markdown]
# Definamos una función para evaluar modelos más facilmente:

# %%
def evaluar_modelos_pasos(X, Y, nro_pasos=25, nro_capas_lstm=1, unidades_capa= [50], loss_= 'mse', act_salida='linear', act_lstm= 'relu'):
    # Normalizamos los datos
    scaler_X = MinMaxScaler()
    scaler_Y = MinMaxScaler()
    X_scaled = scaler_X.fit_transform(X)
    Y_scaled = scaler_Y.fit_transform(Y)

    # Generamos listas vacías para almacenar datos
    lista_loss = []
    lista_pasos = []

    # Dividimos los datos en conjuntos de entrenamiento y prueba
    X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y_scaled, test_size=0.2, shuffle=False)

    for pasos in range(1,nro_pasos):

        # Reshape de los datos para que sean 3D (número de muestras, número de pasos de tiempo, número de características)
        X_train_reshaped, Y_train_reshaped = generador_X_Y_lag(X_train, Y_train, pasos)
        X_test_reshaped, Y_test_reshaped = generador_X_Y_lag(X_test, Y_test, pasos)

        # Construimos el modelo LSTM
        model = Sequential()
        for i in range(nro_capas_lstm):
            model.add(LSTM(units=unidades_capa[i], activation=act_lstm, input_shape=(X_train_reshaped.shape[1], X_train_reshaped.shape[2])))
        model.add(Dense(units=Y_train_reshaped.shape[1], activation= act_salida))  # Capa de salida con tantas neuronas como variables de salida
        model.compile(optimizer='adam', loss=loss_)  # Compilación del modelo

        # Entrenamos el modelo
        model.fit(X_train_reshaped, Y_train_reshaped, epochs=50, batch_size=32, validation_data=(X_test_reshaped, Y_test_reshaped), verbose=0)

        # Evaluamos del modelo
        loss = model.evaluate(X_test_reshaped, Y_test_reshaped)
        print('Número de pasos',pasos ,'Loss (MSE):', loss)
        lista_pasos.append(pasos)
        lista_loss.append(loss)

    sns.lineplot(x= lista_pasos, y=lista_loss)
    plt.title('Evaluación de modelos LSTM')
    plt.xlabel('Número de pasos')
    plt.ylabel('Loss')
    plt.show()

    mejor_paso = lista_pasos[lista_loss.index(min(lista_loss))]

    return mejor_paso

# %% [markdown]
# Definamos una función también para construir un modelo y hacer su curva de aprendizaje:

# %%
def construir_modelo(X, Y, nro_pasos, nro_capas_lstm=1, unidades_capa= [50], loss_= 'mse', act_salida='linear', act_lstm= 'relu'):
    # Normalizar los datos
    scaler_X = MinMaxScaler()
    scaler_Y = MinMaxScaler()
    X_scaled = scaler_X.fit_transform(X)
    Y_scaled = scaler_Y.fit_transform(Y)

    # Dividir los datos en conjuntos de entrenamiento y prueba
    X_train, X_test, Y_train, Y_test = train_test_split(X_scaled, Y_scaled, test_size=0.2, shuffle=False)

    # Reshape de los datos para que sean 3D (número de muestras, número de pasos de tiempo, número de características)
    X_train_reshaped, Y_train_reshaped = generador_X_Y_lag(X_train, Y_train, nro_pasos)
    X_test_reshaped, Y_test_reshaped = generador_X_Y_lag(X_test, Y_test, nro_pasos)

    # Construimos el modelo LSTM
    model = Sequential()
    if nro_capas_lstm > 1:

        model.add(LSTM(units=unidades_capa[0], activation=act_lstm, input_shape=(X_train_reshaped.shape[1], X_train_reshaped.shape[2]), return_sequences=True))
        for i in range(1, nro_capas_lstm-1):
            model.add(LSTM(units=unidades_capa[i], activation=act_lstm, return_sequences=True))
        model.add(LSTM(units=unidades_capa[-1], activation=act_lstm))
        model.add(Dense(units=Y_train_reshaped.shape[1], activation=act_salida))
    
    if nro_capas_lstm == 1:
        model.add(LSTM(units=unidades_capa[0], activation=act_lstm, input_shape=(X_train_reshaped.shape[1], X_train_reshaped.shape[2])))
        model.add(Dense(units=Y_train_reshaped.shape[1], activation=act_salida))

    model.compile(optimizer='adam', loss=loss_)  # Compilación del modelo 
    
    model.summary()

    # Entrenamos el modelo y guardamos el historial de entrenamiento
    history = model.fit(X_train_reshaped, Y_train_reshaped, epochs=50, batch_size=32, validation_data=(X_test_reshaped, Y_test_reshaped), verbose=0)

    # Extraemos los valores de la función de pérdida del historial de entrenamiento
    train_loss = history.history['loss']
    val_loss = history.history['val_loss']
    
    final_loss = history.history['val_loss'][-1]
    print("Valor final de Loss:", final_loss)
    
    # Graficamos la curva de aprendizaje
    plt.plot(train_loss, label='Train Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Curva de Aprendizaje')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

    return model, X_test_reshaped, Y_test_reshaped, scaler_Y

# %% [markdown]
# Probemos la cantidad de pasos nuevamente:

# %%
mejor_paso = evaluar_modelos_pasos(X, Y, nro_pasos= 25)
# Out:
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0074
# Número de pasos 1 Loss (MSE): 0.0074339816346764565
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0077
# Número de pasos 2 Loss (MSE): 0.007688830140978098
# 9/9 [==============================] - 0s 22ms/step - loss: 0.0078
# Número de pasos 3 Loss (MSE): 0.007838776335120201
# 9/9 [==============================] - 0s 0s/step - loss: 0.0079
# Número de pasos 4 Loss (MSE): 0.007901097647845745
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0084
# Número de pasos 5 Loss (MSE): 0.00838435348123312
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0100
# Número de pasos 6 Loss (MSE): 0.010002950206398964
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0079
# Número de pasos 7 Loss (MSE): 0.007875506766140461
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0077
# Número de pasos 8 Loss (MSE): 0.0077133504673838615
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0086
# Número de pasos 9 Loss (MSE): 0.008596168830990791
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0092
# Número de pasos 10 Loss (MSE): 0.009156017564237118
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0080
# Número de pasos 11 Loss (MSE): 0.008005947805941105
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0106
# Número de pasos 12 Loss (MSE): 0.010584773495793343
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0079
# Número de pasos 13 Loss (MSE): 0.007875371724367142
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0093
# Número de pasos 14 Loss (MSE): 0.00925609190016985
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0083
# Número de pasos 15 Loss (MSE): 0.008277258835732937
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0079
# Número de pasos 16 Loss (MSE): 0.0079080481082201
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0085
# Número de pasos 17 Loss (MSE): 0.008498945273458958
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0080
# Número de pasos 18 Loss (MSE): 0.00797773152589798
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0079
# Número de pasos 19 Loss (MSE): 0.007931961677968502
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0097
# Número de pasos 20 Loss (MSE): 0.00966263934969902
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0090
# Número de pasos 21 Loss (MSE): 0.00897140335291624
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0093
# Número de pasos 22 Loss (MSE): 0.009332437068223953
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0080
# Número de pasos 23 Loss (MSE): 0.008016608655452728
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0086
# Número de pasos 24 Loss (MSE): 0.008611328899860382

# %%
print('El mejor paso de tiempo es:', mejor_paso)
# Out:
# El mejor paso de tiempo es: 1

# %% [markdown]
# Vemos un mínimo en {{ mejor_paso }} pasos. Probemos ese modelo:

# %%
model, X_test_reshaped, Y_test_reshaped = construir_modelo(X, Y, nro_pasos=mejor_paso)
# Out:
# Model: "sequential_211"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_211 (LSTM)             (None, 50)                12800
#
#  dense_211 (Dense)           (None, 5)                 255
#
# =================================================================
# Total params: 13055 (51.00 KB)
# Trainable params: 13055 (51.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 37/37 [==============================] - 1s 7ms/step - loss: 0.0749 - val_loss: 0.0219
# Epoch 2/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0261 - val_loss: 0.0321
# Epoch 3/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0176 - val_loss: 0.0183
# Epoch 4/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0132 - val_loss: 0.0125
# Epoch 5/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0108 - val_loss: 0.0099
# Epoch 6/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0097 - val_loss: 0.0093
# Epoch 7/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0091 - val_loss: 0.0091
# Epoch 8/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0087 - val_loss: 0.0088
# Epoch 9/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0082 - val_loss: 0.0087
# Epoch 10/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0080 - val_loss: 0.0089
# Epoch 11/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0077 - val_loss: 0.0086
# Epoch 12/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0076 - val_loss: 0.0084
# Epoch 13/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0074 - val_loss: 0.0086
# Epoch 14/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0073 - val_loss: 0.0084
# Epoch 15/50
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0072 - val_loss: 0.0083
# Epoch 16/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0071 - val_loss: 0.0083
# Epoch 17/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0071 - val_loss: 0.0083
# Epoch 18/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.0082
# Epoch 19/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0081
# Epoch 20/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0069 - val_loss: 0.0082
# Epoch 21/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0082
# Epoch 22/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0068 - val_loss: 0.0079
# Epoch 23/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0080
# Epoch 24/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0067 - val_loss: 0.0077
# Epoch 25/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0078
# Epoch 26/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0083
# Epoch 27/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0076
# Epoch 28/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0077
# Epoch 29/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0076
# Epoch 30/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0076
# Epoch 31/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0075
# Epoch 32/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0074
# Epoch 33/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0077
# Epoch 34/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0074
# Epoch 35/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0074
# Epoch 36/50
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0062 - val_loss: 0.0074
# Epoch 37/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0072
# Epoch 38/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0072
# Epoch 39/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0075
# Epoch 40/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0073
# Epoch 41/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0071
# Epoch 42/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0072
# Epoch 43/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0072
# Epoch 44/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0071
# Epoch 45/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0070
# Epoch 46/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0072
# Epoch 47/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0071
# Epoch 48/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0072
# Epoch 49/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 0.0072
# Epoch 50/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0071

# %%
graficar_pred_test(X_test_reshaped, Y_test_reshaped)
# Out:
# 10/10 [==============================] - 0s 0s/step

# %% [markdown]
# Vemos que el modelo mejora mucho. Sin embargo, puede haber overfitting. Veamos si podemos mejorarlo añadiendo alguna variable. Por ejemplo, probemos agregar la variable 'número de día de la semana':

# %%
df.head()
# Out:
#        fecha  hora  temperature_2m  rain  relative_humidity_2m  snowfall  \
# 0 2023-11-01   0.0          8.6725   0.1             60.153034       0.0
# 1 2023-11-01   1.0          8.5725   0.0             60.344471       0.0
# 2 2023-11-01   2.0          8.3225   0.1             62.933163       0.0
# 3 2023-11-01   3.0          8.0725   0.0             66.100021       0.0
# 4 2023-11-01   4.0          7.7725   0.0             72.938622       0.0
#
#    Bronx  Brooklyn  Manhattan  Queens  Staten Island   año  mes  dia
# 0      3        12       2196     232              1  2023   11    1
# 1      2        12       1521      55              0  2023   11    1
# 2      3         8       1214      16              0  2023   11    1
# 3      0        13        854      20              0  2023   11    1
# 4     12        20        654      25              0  2023   11    1

# %%
df['nro_de_dia'] = df['fecha'].dt.weekday + 1
df.head()
# Out:
#        fecha  hora  temperature_2m  rain  relative_humidity_2m  snowfall  \
# 3 2023-11-01   0.0          8.6725   0.1             60.153034       0.0
# 4 2023-11-01   1.0          8.5725   0.0             60.344471       0.0
# 5 2023-11-01   2.0          8.3225   0.1             62.933163       0.0
# 6 2023-11-01   3.0          8.0725   0.0             66.100021       0.0
# 7 2023-11-01   4.0          7.7725   0.0             72.938622       0.0
#
#    Bronx  Brooklyn  Manhattan  Queens  Staten Island   año  mes  dia  \
# 3      3        12       2196     232              1  2023   11    1
# 4      2        12       1521      55              0  2023   11    1
# 5      3         8       1214      16              0  2023   11    1
# 6      0        13        854      20              0  2023   11    1
# 7     12        20        654      25              0  2023   11    1
#
#    nro_de_dia
# 3           3
# 4           3
# 5           3
# 6           3
# 7           3

# %%
columnas_X_nuevas = ['año', 'mes', 'dia', 'hora', 'nro_de_dia', 'temperature_2m', 'rain', 'relative_humidity_2m', 'snowfall']
X_nueva = df[columnas_X_nuevas]

columnas_Y= ['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island']
Y_nueva = df[columnas_Y]

# %% [markdown]
# Probemos nuevamente la cantidad de pasos de tiempo adecuada

# %%
mejor_paso = evaluar_modelos_pasos(X_nueva, Y_nueva)
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0075
# Número de pasos 1 Loss (MSE): 0.007456895895302296
# 10/10 [==============================] - 0s 0s/step - loss: 0.0088
# Número de pasos 2 Loss (MSE): 0.008767283521592617
# 9/9 [==============================] - 0s 753us/step - loss: 0.0087
# Número de pasos 3 Loss (MSE): 0.008679872378706932
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0095
# Número de pasos 4 Loss (MSE): 0.009489447809755802
# 9/9 [==============================] - 0s 1ms/step - loss: 0.0100
# Número de pasos 5 Loss (MSE): 0.010008654557168484
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0102
# Número de pasos 6 Loss (MSE): 0.010202274657785892
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0104
# Número de pasos 7 Loss (MSE): 0.010380249470472336
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0109
# Número de pasos 8 Loss (MSE): 0.01090906374156475
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0095
# Número de pasos 9 Loss (MSE): 0.009501124732196331
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0128
# Número de pasos 10 Loss (MSE): 0.01276914682239294
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0087
# Número de pasos 11 Loss (MSE): 0.008652869611978531
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0096
# Número de pasos 12 Loss (MSE): 0.009601053781807423
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0090
# Número de pasos 13 Loss (MSE): 0.009031789377331734
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0092
# Número de pasos 14 Loss (MSE): 0.009196176193654537
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0095
# Número de pasos 15 Loss (MSE): 0.009538092650473118
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0101
# Número de pasos 16 Loss (MSE): 0.010084733366966248
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0085
# Número de pasos 17 Loss (MSE): 0.00849125161767006
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0098
# Número de pasos 18 Loss (MSE): 0.009821239858865738
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0099
# Número de pasos 19 Loss (MSE): 0.009900888428092003
# 8/8 [==============================] - 0s 0s/step - loss: 0.0092
# Número de pasos 20 Loss (MSE): 0.009156223386526108
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0101
# Número de pasos 21 Loss (MSE): 0.010062314569950104
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0094
# Número de pasos 22 Loss (MSE): 0.009399278089404106
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0080
# Número de pasos 23 Loss (MSE): 0.008046493865549564
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0094
# Número de pasos 24 Loss (MSE): 0.009372039698064327
# 1

# %%
print('El mejor paso de tiempo es:', mejor_paso)
# Out:
# El mejor paso de tiempo es: 1

# %%
modelo, X_test_reshaped, Y_test_reshaped = construir_modelo(X, Y, nro_pasos=mejor_paso)
# Out:
# Model: "sequential_237"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_237 (LSTM)             (None, 50)                12800
#
#  dense_237 (Dense)           (None, 5)                 255
#
# =================================================================
# Total params: 13055 (51.00 KB)
# Trainable params: 13055 (51.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 37/37 [==============================] - 1s 7ms/step - loss: 0.0931 - val_loss: 0.0385
# Epoch 2/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0492 - val_loss: 0.0233
# Epoch 3/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0247 - val_loss: 0.0278
# Epoch 4/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0182 - val_loss: 0.0184
# Epoch 5/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0139 - val_loss: 0.0125
# Epoch 6/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0116 - val_loss: 0.0116
# Epoch 7/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0105 - val_loss: 0.0111
# Epoch 8/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0097 - val_loss: 0.0109
# Epoch 9/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0092 - val_loss: 0.0105
# Epoch 10/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0088 - val_loss: 0.0102
# Epoch 11/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0086 - val_loss: 0.0097
# Epoch 12/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0083 - val_loss: 0.0094
# Epoch 13/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0081 - val_loss: 0.0092
# Epoch 14/50
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0079 - val_loss: 0.0088
# Epoch 15/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0078 - val_loss: 0.0089
# Epoch 16/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0076 - val_loss: 0.0094
# Epoch 17/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0075 - val_loss: 0.0088
# Epoch 18/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0074 - val_loss: 0.0084
# Epoch 19/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0073 - val_loss: 0.0087
# Epoch 20/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0072 - val_loss: 0.0086
# Epoch 21/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.0084
# Epoch 22/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.0083
# Epoch 23/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0083
# Epoch 24/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0069 - val_loss: 0.0087
# Epoch 25/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0081
# Epoch 26/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0080
# Epoch 27/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0081
# Epoch 28/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0067 - val_loss: 0.0080
# Epoch 29/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0066 - val_loss: 0.0077
# Epoch 30/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0079
# Epoch 31/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0078
# Epoch 32/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0065 - val_loss: 0.0077
# Epoch 33/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0078
# Epoch 34/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0064 - val_loss: 0.0077
# Epoch 35/50
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0064 - val_loss: 0.0079
# Epoch 36/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0076
# Epoch 37/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0077
# Epoch 38/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0063 - val_loss: 0.0075
# Epoch 39/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0078
# Epoch 40/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0077
# Epoch 41/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0073
# Epoch 42/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0076
# Epoch 43/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0073
# Epoch 44/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0062 - val_loss: 0.0074
# Epoch 45/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0077
# Epoch 46/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0077
# Epoch 47/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0074
# Epoch 48/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0075
# Epoch 49/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0074
# Epoch 50/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0074

# %%
graficar_pred_test(X_test_reshaped, Y_test_reshaped)
# Out:
# 10/10 [==============================] - 0s 2ms/step

# %% [markdown]
# Debido a que vemos que hay demandas negativas en la respuesta del modelo, vamos a evaluar utilizar la métrica MAE:

# %%
mejor_paso = evaluar_modelos_pasos(X_nueva, Y_nueva, loss_='mae')
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0554
# Número de pasos 1 Loss (MSE): 0.05537039041519165
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0544
# Número de pasos 2 Loss (MSE): 0.05442085862159729
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0535
# Número de pasos 3 Loss (MSE): 0.05350629240274429
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0613
# Número de pasos 4 Loss (MSE): 0.06130744516849518
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0586
# Número de pasos 5 Loss (MSE): 0.058640286326408386
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0534
# Número de pasos 6 Loss (MSE): 0.05339591205120087
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0568
# Número de pasos 7 Loss (MSE): 0.05680006742477417
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0595
# Número de pasos 8 Loss (MSE): 0.0595465824007988
# 9/9 [==============================] - 0s 9ms/step - loss: 0.0572
# Número de pasos 9 Loss (MSE): 0.05715467780828476
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0609
# Número de pasos 10 Loss (MSE): 0.060914404690265656
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0616
# Número de pasos 11 Loss (MSE): 0.0615898072719574
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0660
# Número de pasos 12 Loss (MSE): 0.06604956090450287
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0614
# Número de pasos 13 Loss (MSE): 0.06139151751995087
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0686
# Número de pasos 14 Loss (MSE): 0.06857606768608093
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0613
# Número de pasos 15 Loss (MSE): 0.06127939000725746
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0592
# Número de pasos 16 Loss (MSE): 0.05920799821615219
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0636
# Número de pasos 17 Loss (MSE): 0.06362295150756836
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0571
# Número de pasos 18 Loss (MSE): 0.057086240500211716
# 8/8 [==============================] - 0s 33ms/step - loss: 0.0546
# Número de pasos 19 Loss (MSE): 0.05459946393966675
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0600
# Número de pasos 20 Loss (MSE): 0.06003263592720032
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0600
# Número de pasos 21 Loss (MSE): 0.05999075993895531
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0592
# Número de pasos 22 Loss (MSE): 0.0591554157435894
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0581
# Número de pasos 23 Loss (MSE): 0.05808451399207115
# 8/8 [==============================] - 0s 9ms/step - loss: 0.0588
# Número de pasos 24 Loss (MSE): 0.05875176563858986

# %%
print('El mejor paso de tiempo es:' , mejor_paso)
# Out:
# El mejor paso de tiempo es: 6

# %%
modelo, X_test_reshaped, Y_test_reshaped = construir_modelo(X_nueva, Y_nueva, nro_pasos=mejor_paso, loss_= 'mae')
# Out:
# Model: "sequential_262"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_262 (LSTM)             (None, 50)                18000
#
#  dense_262 (Dense)           (None, 5)                 255
#
# =================================================================
# Total params: 18255 (71.31 KB)
# Trainable params: 18255 (71.31 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 37/37 [==============================] - 1s 8ms/step - loss: 0.1279 - val_loss: 0.0980
# Epoch 2/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0815 - val_loss: 0.0995
# Epoch 3/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0690 - val_loss: 0.0845
# Epoch 4/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0628 - val_loss: 0.0751
# Epoch 5/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0596 - val_loss: 0.0741
# Epoch 6/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0577 - val_loss: 0.0764
# Epoch 7/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0571 - val_loss: 0.0773
# Epoch 8/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0553 - val_loss: 0.0695
# Epoch 9/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0541 - val_loss: 0.0718
# Epoch 10/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0529 - val_loss: 0.0681
# Epoch 11/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0522 - val_loss: 0.0722
# Epoch 12/50
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0509 - val_loss: 0.0666
# Epoch 13/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0502 - val_loss: 0.0662
# Epoch 14/50
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0507 - val_loss: 0.0651
# Epoch 15/50
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0490 - val_loss: 0.0632
# Epoch 16/50
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0487 - val_loss: 0.0647
# Epoch 17/50
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0479 - val_loss: 0.0673
# Epoch 18/50
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0484 - val_loss: 0.0654
# Epoch 19/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0474 - val_loss: 0.0686
# Epoch 20/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0472 - val_loss: 0.0621
# Epoch 21/50
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0465 - val_loss: 0.0634
# Epoch 22/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0462 - val_loss: 0.0635
# Epoch 23/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0462 - val_loss: 0.0614
# Epoch 24/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0454 - val_loss: 0.0654
# Epoch 25/50
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0450 - val_loss: 0.0670
# Epoch 26/50
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0451 - val_loss: 0.0635
# Epoch 27/50
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0453 - val_loss: 0.0616
# Epoch 28/50
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0442 - val_loss: 0.0613
# Epoch 29/50
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0434 - val_loss: 0.0621
# Epoch 30/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0430 - val_loss: 0.0622
# Epoch 31/50
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0431 - val_loss: 0.0610
# Epoch 32/50
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0433 - val_loss: 0.0606
# Epoch 33/50
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0429 - val_loss: 0.0569
# Epoch 34/50
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0433 - val_loss: 0.0594
# Epoch 35/50
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0424 - val_loss: 0.0593
# Epoch 36/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0417 - val_loss: 0.0579
# Epoch 37/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0414 - val_loss: 0.0630
# Epoch 38/50
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0416 - val_loss: 0.0601
# Epoch 39/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0413 - val_loss: 0.0595
# Epoch 40/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0409 - val_loss: 0.0598
# Epoch 41/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0407 - val_loss: 0.0620
# Epoch 42/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0405 - val_loss: 0.0606
# Epoch 43/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0412 - val_loss: 0.0581
# Epoch 44/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0404 - val_loss: 0.0606
# Epoch 45/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0404 - val_loss: 0.0579
# Epoch 46/50
# 37/37 [==============================] - 0s 5ms/step - loss: 0.0404 - val_loss: 0.0621
# Epoch 47/50
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0399 - val_loss: 0.0600
# Epoch 48/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0397 - val_loss: 0.0619
# Epoch 49/50
# 37/37 [==============================] - 0s 7ms/step - loss: 0.0397 - val_loss: 0.0593
# Epoch 50/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0398 - val_loss: 0.0637

# %%
X_test_reshaped.shape
# Out:
# (281, 6, 39)

# %%
Y_test_reshaped.shape
# Out:
# (281, 5)

# %%
graficar_pred_test(X_test_reshaped, Y_test_reshaped, modelo)
# Out:
# 9/9 [==============================] - 0s 2ms/step

# %% [markdown]
# Seguimos viendo que, a valores bajos o cero de demanda, el modelo predice demanda negativa. Probemos con activación 'Relu' en la capa de salida:

# %%
mejor_paso = evaluar_modelos_pasos(X_nueva, Y_nueva, act_salida= 'relu')
# Out:
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0336
# Número de pasos 1 Loss (MSE): 0.033614810556173325
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0082
# Número de pasos 2 Loss (MSE): 0.008220975287258625
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0084
# Número de pasos 3 Loss (MSE): 0.00836149975657463
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0101
# Número de pasos 4 Loss (MSE): 0.010126105509698391
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0097
# Número de pasos 5 Loss (MSE): 0.009711046703159809
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0086
# Número de pasos 6 Loss (MSE): 0.008608565665781498
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0099
# Número de pasos 7 Loss (MSE): 0.009911715053021908
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0106
# Número de pasos 8 Loss (MSE): 0.010586421005427837
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0091
# Número de pasos 9 Loss (MSE): 0.009081851691007614
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0091
# Número de pasos 10 Loss (MSE): 0.0090599674731493
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0085
# Número de pasos 11 Loss (MSE): 0.008502625860273838
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0330
# Número de pasos 12 Loss (MSE): 0.032983891665935516
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0089
# Número de pasos 13 Loss (MSE): 0.00894143059849739
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0089
# Número de pasos 14 Loss (MSE): 0.008944489993155003
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0087
# Número de pasos 15 Loss (MSE): 0.008665183559060097
# 9/9 [==============================] - 0s 8ms/step - loss: 0.0381
# Número de pasos 16 Loss (MSE): 0.0380973257124424
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0103
# Número de pasos 17 Loss (MSE): 0.010302734561264515
# 9/9 [==============================] - 0s 6ms/step - loss: 0.0080
# Número de pasos 18 Loss (MSE): 0.008009455166757107
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0524
# Número de pasos 19 Loss (MSE): 0.0523601658642292
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0394
# Número de pasos 20 Loss (MSE): 0.039421096444129944
# 8/8 [==============================] - 0s 1ms/step - loss: 0.0099
# Número de pasos 21 Loss (MSE): 0.009871667250990868
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0085
# Número de pasos 22 Loss (MSE): 0.008457669988274574
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0306
# Número de pasos 23 Loss (MSE): 0.030625877901911736
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0082
# Número de pasos 24 Loss (MSE): 0.008237280882894993

# %%
print('Mejor paso de tiempo:', mejor_paso)
# Out:
# Mejor paso de tiempo: 18

# %%
modelo, X_test_reshaped, Y_test_reshaped = construir_modelo(X_nueva, Y_nueva, act_salida= 'relu', nro_pasos=mejor_paso)
# Out:
# Model: "sequential_287"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_287 (LSTM)             (None, 50)                30000
#
#  dense_287 (Dense)           (None, 5)                 255
#
# =================================================================
# Total params: 30255 (118.18 KB)
# Trainable params: 30255 (118.18 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 36/36 [==============================] - 1s 13ms/step - loss: 0.0410 - val_loss: 0.0348
# Epoch 2/50
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0252 - val_loss: 0.0314
# Epoch 3/50
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0230 - val_loss: 0.0294
# Epoch 4/50
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0219 - val_loss: 0.0280
# Epoch 5/50
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0211 - val_loss: 0.0268
# Epoch 6/50
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0207 - val_loss: 0.0281
# Epoch 7/50
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0204 - val_loss: 0.0255
# Epoch 8/50
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0200 - val_loss: 0.0261
# Epoch 9/50
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0198 - val_loss: 0.0263
# Epoch 10/50
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0195 - val_loss: 0.0254
# Epoch 11/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0194 - val_loss: 0.0245
# Epoch 12/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0192 - val_loss: 0.0245
# Epoch 13/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0193 - val_loss: 0.0247
# Epoch 14/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0192 - val_loss: 0.0246
# Epoch 15/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0191 - val_loss: 0.0242
# Epoch 16/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0190 - val_loss: 0.0261
# Epoch 17/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0191 - val_loss: 0.0244
# Epoch 18/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0189 - val_loss: 0.0262
# Epoch 19/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0188 - val_loss: 0.0244
# Epoch 20/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0189 - val_loss: 0.0244
# Epoch 21/50
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0188 - val_loss: 0.0247
# Epoch 22/50
# 36/36 [==============================] - 0s 9ms/step - loss: 0.0188 - val_loss: 0.0254
# Epoch 23/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0188 - val_loss: 0.0237
# Epoch 24/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0187 - val_loss: 0.0243
# Epoch 25/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0186 - val_loss: 0.0239
# Epoch 26/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0186 - val_loss: 0.0235
# Epoch 27/50
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0187 - val_loss: 0.0245
# Epoch 28/50
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0186 - val_loss: 0.0231
# Epoch 29/50
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0185 - val_loss: 0.0235
# Epoch 30/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0186 - val_loss: 0.0243
# Epoch 31/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0185 - val_loss: 0.0239
# Epoch 32/50
# 36/36 [==============================] - 0s 11ms/step - loss: 0.0184 - val_loss: 0.0241
# Epoch 33/50
# 36/36 [==============================] - 0s 8ms/step - loss: 0.0183 - val_loss: 0.0238
# Epoch 34/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0183 - val_loss: 0.0234
# Epoch 35/50
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0184 - val_loss: 0.0231
# Epoch 36/50
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0183 - val_loss: 0.0240
# Epoch 37/50
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0183 - val_loss: 0.0237
# Epoch 38/50
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0182 - val_loss: 0.0236
# Epoch 39/50
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0182 - val_loss: 0.0241
# Epoch 40/50
# 36/36 [==============================] - 0s 5ms/step - loss: 0.0184 - val_loss: 0.0228
# Epoch 41/50
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0183 - val_loss: 0.0242
# Epoch 42/50
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0182 - val_loss: 0.0241
# Epoch 43/50
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0181 - val_loss: 0.0239
# Epoch 44/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0182 - val_loss: 0.0232
# Epoch 45/50
# 36/36 [==============================] - 0s 10ms/step - loss: 0.0181 - val_loss: 0.0242
# Epoch 46/50
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0184 - val_loss: 0.0239
# Epoch 47/50
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0181 - val_loss: 0.0243
# Epoch 48/50
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0181 - val_loss: 0.0235
# Epoch 49/50
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0181 - val_loss: 0.0235
# Epoch 50/50
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0181 - val_loss: 0.0237

# %%
graficar_pred_test(X_test_reshaped, Y_test_reshaped, modelo)
# Out:
# 9/9 [==============================] - 0s 3ms/step

# %% [markdown]
# La activación Relu en la capa de salida, elimina los negativos pero los deja en cero. Probemos con la activación sigmoide:

# %%
mejor_paso = evaluar_modelos_pasos(X_nueva, Y_nueva, act_salida= 'sigmoid')
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0080
# Número de pasos 1 Loss (MSE): 0.00801320094615221
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0076
# Número de pasos 2 Loss (MSE): 0.007579926401376724
# 9/9 [==============================] - 0s 457us/step - loss: 0.0093
# Número de pasos 3 Loss (MSE): 0.00930507481098175
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0093
# Número de pasos 4 Loss (MSE): 0.009334013797342777
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0090
# Número de pasos 5 Loss (MSE): 0.009022149257361889
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0099
# Número de pasos 6 Loss (MSE): 0.009860148653388023
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0098
# Número de pasos 7 Loss (MSE): 0.009770149365067482
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0080
# Número de pasos 8 Loss (MSE): 0.008044077083468437
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0101
# Número de pasos 9 Loss (MSE): 0.010079327039420605
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0101
# Número de pasos 10 Loss (MSE): 0.010055926628410816
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0095
# Número de pasos 11 Loss (MSE): 0.00953989289700985
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0089
# Número de pasos 12 Loss (MSE): 0.008877653628587723
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0090
# Número de pasos 13 Loss (MSE): 0.008974960073828697
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0098
# Número de pasos 14 Loss (MSE): 0.0097761619836092
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0090
# Número de pasos 15 Loss (MSE): 0.00902473647147417
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0096
# Número de pasos 16 Loss (MSE): 0.009618275798857212
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0089
# Número de pasos 17 Loss (MSE): 0.008928816765546799
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0092
# Número de pasos 18 Loss (MSE): 0.00915312860161066
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0093
# Número de pasos 19 Loss (MSE): 0.009261209517717361
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0094
# Número de pasos 20 Loss (MSE): 0.009358890354633331
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0117
# Número de pasos 21 Loss (MSE): 0.011738373897969723
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0094
# Número de pasos 22 Loss (MSE): 0.009379473514854908
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0106
# Número de pasos 23 Loss (MSE): 0.010635978542268276
# 8/8 [==============================] - 0s 2ms/step - loss: 0.0096
# Número de pasos 24 Loss (MSE): 0.009553719311952591

# %%
print('El mejor paso de tiempo es:', mejor_paso)
# Out:
# El mejor paso de tiempo es: 2

# %%
modelo, X_test_reshaped, Y_test_reshaped = construir_modelo(X_nueva, Y_nueva, act_salida='sigmoid', nro_pasos=mejor_paso)
# Out:
# Model: "sequential_314"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_314 (LSTM)             (None, 50)                14000
#
#  dense_314 (Dense)           (None, 5)                 255
#
# =================================================================
# Total params: 14255 (55.68 KB)
# Trainable params: 14255 (55.68 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/50
# 37/37 [==============================] - 1s 7ms/step - loss: 0.1075 - val_loss: 0.0707
# Epoch 2/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0535 - val_loss: 0.0336
# Epoch 3/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0335 - val_loss: 0.0232
# Epoch 4/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0248 - val_loss: 0.0176
# Epoch 5/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0186 - val_loss: 0.0149
# Epoch 6/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0148 - val_loss: 0.0129
# Epoch 7/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0127 - val_loss: 0.0116
# Epoch 8/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0114 - val_loss: 0.0108
# Epoch 9/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0105 - val_loss: 0.0104
# Epoch 10/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0098 - val_loss: 0.0100
# Epoch 11/50
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0093 - val_loss: 0.0096
# Epoch 12/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0089 - val_loss: 0.0092
# Epoch 13/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0084 - val_loss: 0.0094
# Epoch 14/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0081 - val_loss: 0.0089
# Epoch 15/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0078 - val_loss: 0.0092
# Epoch 16/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0077 - val_loss: 0.0091
# Epoch 17/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0075 - val_loss: 0.0091
# Epoch 18/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0074 - val_loss: 0.0089
# Epoch 19/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0073 - val_loss: 0.0087
# Epoch 20/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0072 - val_loss: 0.0092
# Epoch 21/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0072 - val_loss: 0.0092
# Epoch 22/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0070 - val_loss: 0.0085
# Epoch 23/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0086
# Epoch 24/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0069 - val_loss: 0.0089
# Epoch 25/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0084
# Epoch 26/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0083
# Epoch 27/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0068 - val_loss: 0.0081
# Epoch 28/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0067 - val_loss: 0.0085
# Epoch 29/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0086
# Epoch 30/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0082
# Epoch 31/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0082
# Epoch 32/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0065 - val_loss: 0.0086
# Epoch 33/50
# 37/37 [==============================] - 0s 6ms/step - loss: 0.0064 - val_loss: 0.0082
# Epoch 34/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0064 - val_loss: 0.0082
# Epoch 35/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0064 - val_loss: 0.0085
# Epoch 36/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0080
# Epoch 37/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0063 - val_loss: 0.0084
# Epoch 38/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0079
# Epoch 39/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0062 - val_loss: 0.0082
# Epoch 40/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 41/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0080
# Epoch 42/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0061 - val_loss: 0.0077
# Epoch 43/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0081
# Epoch 44/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0061 - val_loss: 0.0080
# Epoch 45/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 0.0076
# Epoch 46/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0060 - val_loss: 0.0078
# Epoch 47/50
# 37/37 [==============================] - 0s 2ms/step - loss: 0.0060 - val_loss: 0.0079
# Epoch 48/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0082
# Epoch 49/50
# 37/37 [==============================] - 0s 4ms/step - loss: 0.0058 - val_loss: 0.0079
# Epoch 50/50
# 37/37 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0076

# %%
graficar_pred_test(X_test_reshaped, Y_test_reshaped, modelo)
# Out:
# 10/10 [==============================] - 0s 2ms/step

# %% [markdown]
# Evaluemos ahora la cantidad de capas LSTM y de unidades en cada capa:

# %%
for i in range(1,6):
    print('Número de capas LSTM= ', i)
    modelo, X_test_reshaped, Y_test_reshaped = construir_modelo(X_nueva, Y_nueva, nro_pasos=2, 
                                                                      nro_capas_lstm=i, unidades_capa=[50, 40, 30, 20, 10], act_salida='sigmoid')
# Out:
# Número de capas LSTM=  1
# Model: "sequential_336"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_352 (LSTM)             (None, 50)                14000
#
#  dense_333 (Dense)           (None, 5)                 255
#
# =================================================================
# Total params: 14255 (55.68 KB)
# Trainable params: 14255 (55.68 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Valor final de Loss: 0.007683870382606983
# Número de capas LSTM=  2
# Model: "sequential_337"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_353 (LSTM)             (None, 2, 50)             14000
#
#  lstm_354 (LSTM)             (None, 10)                2440
#
#  dense_334 (Dense)           (None, 5)                 55
#
# =================================================================
# Total params: 16495 (64.43 KB)
# Trainable params: 16495 (64.43 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Valor final de Loss: 0.010048785246908665
# Número de capas LSTM=  3
# Model: "sequential_338"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_355 (LSTM)             (None, 2, 50)             14000
#
#  lstm_356 (LSTM)             (None, 2, 40)             14560
#
#  lstm_357 (LSTM)             (None, 10)                2040
#
#  dense_335 (Dense)           (None, 5)                 55
#
# =================================================================
# Total params: 30655 (119.75 KB)
# Trainable params: 30655 (119.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Valor final de Loss: 0.00839811097830534
# Número de capas LSTM=  4
# Model: "sequential_339"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_358 (LSTM)             (None, 2, 50)             14000
#
#  lstm_359 (LSTM)             (None, 2, 40)             14560
#
#  lstm_360 (LSTM)             (None, 2, 30)             8520
#
#  lstm_361 (LSTM)             (None, 10)                1640
#
#  dense_336 (Dense)           (None, 5)                 55
#
# =================================================================
# Total params: 38775 (151.46 KB)
# Trainable params: 38775 (151.46 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Valor final de Loss: 0.008688838221132755
# Número de capas LSTM=  5
# Model: "sequential_340"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_362 (LSTM)             (None, 2, 50)             14000
#
#  lstm_363 (LSTM)             (None, 2, 40)             14560
#
#  lstm_364 (LSTM)             (None, 2, 30)             8520
#
#  lstm_365 (LSTM)             (None, 2, 20)             4080
#
#  lstm_366 (LSTM)             (None, 10)                1240
#
#  dense_337 (Dense)           (None, 5)                 55
#
# =================================================================
# Total params: 42455 (165.84 KB)
# Trainable params: 42455 (165.84 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Valor final de Loss: 0.009088112972676754

# %% [markdown]
# Vemos que la menor pérdida la tenemos con una sola capa LSTM

# %% [markdown]
# Ahora probemos cambiando la función de activación de las capas LSTM a 'sigmoid':

# %%
mejor_paso = evaluar_modelos_pasos(X_nueva, Y_nueva, act_salida='sigmoid', act_lstm='sigmoid')
# Out:
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0097
# Número de pasos 1 Loss (MSE): 0.009654797613620758
# 10/10 [==============================] - 0s 519us/step - loss: 0.0098
# Número de pasos 2 Loss (MSE): 0.009823975153267384
# 9/9 [==============================] - 0s 852us/step - loss: 0.0098
# Número de pasos 3 Loss (MSE): 0.009818727150559425
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0093
# Número de pasos 4 Loss (MSE): 0.009301606565713882
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0094
# Número de pasos 5 Loss (MSE): 0.009401513263583183
# 9/9 [==============================] - 0s 507us/step - loss: 0.0089
# Número de pasos 6 Loss (MSE): 0.00889867078512907
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0090
# Número de pasos 7 Loss (MSE): 0.00897534191608429
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0097
# Número de pasos 8 Loss (MSE): 0.009701530449092388
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0104
# Número de pasos 9 Loss (MSE): 0.010383700020611286
# 9/9 [==============================] - 0s 38ms/step - loss: 0.0095
# Número de pasos 10 Loss (MSE): 0.009481053799390793
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0088
# Número de pasos 11 Loss (MSE): 0.008799327537417412
# 9/9 [==============================] - 0s 3ms/step - loss: 0.0080
# Número de pasos 12 Loss (MSE): 0.00800338014960289
# 9/9 [==============================] - 0s 7ms/step - loss: 0.0084
# Número de pasos 13 Loss (MSE): 0.008398305624723434
# 9/9 [==============================] - 0s 2ms/step - loss: 0.0082
# Número de pasos 14 Loss (MSE): 0.008160745725035667
# 9/9 [==============================] - 0s 4ms/step - loss: 0.0084
# Número de pasos 15 Loss (MSE): 0.008444240316748619
# 9/9 [==============================] - 0s 5ms/step - loss: 0.0085
# Número de pasos 16 Loss (MSE): 0.008496076799929142
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0093
# Número de pasos 17 Loss (MSE): 0.009315627627074718
# 9/9 [==============================] - 0s 28ms/step - loss: 0.0096
# Número de pasos 18 Loss (MSE): 0.00957420188933611
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0092
# Número de pasos 19 Loss (MSE): 0.009152006357908249
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0092
# Número de pasos 20 Loss (MSE): 0.009196688421070576
# 8/8 [==============================] - 0s 6ms/step - loss: 0.0094
# Número de pasos 21 Loss (MSE): 0.009353396482765675
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0091
# Número de pasos 22 Loss (MSE): 0.009090198203921318
# 8/8 [==============================] - 0s 7ms/step - loss: 0.0087
# Número de pasos 23 Loss (MSE): 0.008746882900595665
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0089
# Número de pasos 24 Loss (MSE): 0.008863586001098156

# %%
print('El mejor paso de tiempo es:', mejor_paso)
# Out:
# El mejor paso de tiempo es: 12

# %%
modelo, X_test_reshaped, Y_test_reshaped, scaler_Y = construir_modelo(X_nueva, Y_nueva, act_lstm='sigmoid', act_salida='sigmoid', nro_pasos=12)
# Out:
# WARNING:tensorflow:From c:\Users\alter\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\alter\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50)                24000
#
#  dense (Dense)               (None, 5)                 255
#
# =================================================================
# Total params: 24255 (94.75 KB)
# Trainable params: 24255 (94.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# WARNING:tensorflow:From c:\Users\alter\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# Valor final de Loss: 0.008368967100977898

# %%
graficar_pred_test(X_test_reshaped, Y_test_reshaped, modelo, scaler_Y)
# Out:
# 9/9 [==============================] - 0s 2ms/step

# %%
plot_model(modelo, to_file='model_plot.png', show_shapes=True, show_layer_names=True, rankdir='TB')
